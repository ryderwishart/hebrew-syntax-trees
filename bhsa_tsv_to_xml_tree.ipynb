# %% [markdown]
# # Turn BHSA TSV into an XML tree

# %% [markdown]
# ## Import data
#
# First, read in the TSV file and extract the column headers from the first row.

# %%
# path_to_tsv_data = 'tsv/bhsa2017_trunc.csv' # truncated to ~100 lines for testing
path_to_tsv_data = 'tsv/bhsa2017.txt'

delimiter = '\t' # '\t'

selected_headers = [
    'n',
    'otype',
    'in.lex',
    'in.subphrase',
    'in.phrase_atom',
    'in.phrase',
    'in.clause_atom',
    'in.clause',
    'in.sentence_atom',
    'in.sentence',
    'in.half_verse',
    'in.verse',
    'in.chapter',
    'in.book',
    'crossref',
    'mother',
    'book',
    'chapter',
    'code',
    'det',
    'domain',
    'freq_lex',
    'function',
    'g_cons_utf8',
    'g_lex_utf8',
    'g_word_utf8',
    'gloss',
    'gn',
    'label',
    'language',
    'lex_utf8',
    'ls',
    'nametype',
    'nme',
    'nu',
    'number',
    'osm',
    'osm_sf',
    'pargr',
    'pdp',
    'pfm',
    'phono',
    'phono_trailer',
    'prs',
    'prs_gn',
    'prs_nu',
    'prs_ps',
    'ps',
    'qere_trailer_utf8',
    'qere_utf8',
    'rank_lex',
    'rela',
    'sp',
    'st',
    'tab',
    'trailer_utf8',
    'txt',
    'typ',
    'uvf',
    'vbe',
    'vbs',
    'verse',
    'voc_lex_utf8',
    'vs',
    'vt'
 ]

excluded_values = [
    'NA',
    'n/a',
    'none',
    ''
]

# %% [markdown]
# Then, create a dictionary to store the data for each row, keyed by chapter, where the keys are the column headers and the values are the data for that column.

# %%
import csv
from lxml import etree

with open(path_to_tsv_data, 'r') as tsv_file:
    reader = csv.DictReader(tsv_file, delimiter=delimiter)
    data = [row for row in reader]
    headers = reader.fieldnames
    print(headers)
# Out:
# ['n', 'otype', 'in.lex', 'in.subphrase', 'in.phrase_atom', 'in.phrase', 'in.clause_atom', 'in.clause', 'in.sentence_atom', 'in.sentence', 'in.half_verse', 'in.verse', 'in.chapter', 'in.book', 'crossref', 'mother', 'book', 'chapter', 'code', 'det', 'domain', 'freq_lex', 'function', 'g_cons', 'g_cons_utf8', 'g_lex', 'g_lex_utf8', 'g_word', 'g_word_utf8', 'gloss', 'gn', 'label', 'language', 'lex', 'lex_utf8', 'ls', 'nametype', 'nme', 'nu', 'number', 'osm', 'osm_sf', 'pargr', 'pdp', 'pfm', 'phono', 'phono_trailer', 'prs', 'prs_gn', 'prs_nu', 'prs_ps', 'ps', 'qere', 'qere_trailer', 'qere_trailer_utf8', 'qere_utf8', 'rank_lex', 'rela', 'sp', 'st', 'tab', 'trailer', 'trailer_utf8', 'tree', 'treen', 'txt', 'typ', 'uvf', 'vbe', 'vbs', 'verse', 'voc_lex', 'voc_lex_utf8', 'vs', 'vt']

# %%
data = dict()

with open(path_to_tsv_data, 'r') as f:
    reader = csv.DictReader(f, delimiter=delimiter)
    for row in reader:
        data[row['n']] = row

# sentences = [row for row in data if row['otype'] == 'sentence'] # not list but dict
sentences = [row for row in data.values() if row['otype'] == 'sentence']

print('rows: ', len(data), 'sentences: ', len(sentences))
# Out:
# rows:  1446831 sentences:  63717

# %% [markdown]
# ## Parsing functions
#
# Next, create a function to parse the treen string and convert it into an XML tree. The function will take the treen string and the column headers as inputs and return an XML tree.

# %%
# Very slightly adapted from Dirk Roorda code here: https://github.com/ETCBC/bhsa/blob/master/tutorial/utils.py

def _parseTerminal(string):
    if ' ' in string:
        (tag, num) = string.split(' ', 1)
        num = str(int(num) + 1) # Word ids in the table are 1-based
        return tag + '{' + num + '}'
    # elif '{' not in string:
        # print('Warning: no space or curly braces in "{}"'.format(string)) # Note: I think the only time this happens is when the word is a coordination group, with string value 'Ccoor'
    return string


def _parseBrackets(string):
    if string == '':
        return ([], '', None)
    if string[0] == '(':
        rest = string[1:]
        result = []
        error = None
        while rest != '' and rest[0] != ')':
            (thisResult, rest, error) = _parseBrackets(rest)
            if error:
                break
            result.append(thisResult)
        if rest == '':
            error = 'Missing ")" in "{}"'.format(string[1:])
        if len(rest):
            rest = rest[1:]
        return (result, rest, error)
    if string[0] == ')':
        return ('', string[1:], None)
    theOpen = string.find('(')
    theClose = string.find(')')
    if theOpen == -1 and theClose == -1:
        return (_parseTerminal(string), '', None)
    nextPos = None
    if theOpen == -1:
        nextPos = theClose
    else:
        nextPos = theOpen if theClose == -1 else min((theOpen, theClose))
    return (_parseTerminal(string[0:nextPos]), string[nextPos:], None)

# %%
def create_node(tag, tag_name, id):
    node = etree.Element(tag_name)
    matching_row = None
    if id != -1:
        node.set('id', str(id))
        matching_row = data[str(id)]
    
    # Set all node attributes 
    
    if matching_row is None:
        # print('No matching row for id: ', str(id), 'tag: ', tag, 'tag_name: ', tag_name)
        pass
    else:
        # the row is a TSV row, so we need to convert it to a dict using the headers as keys
        attributes = {
            header: matching_row[header] for header in headers if matching_row[header] not in excluded_values and header in selected_headers
        }
        attributes['class'] = tag
        for key, value in attributes.items():
            node.set(key, value)
    
    if tag_name == 'w':
        node.text = matching_row['g_word_utf8']
    
    return node

def create_tree(node_list):
    if len(node_list[1:]) > 0:
        id = None;
        if node_list[0] == 'Ccoor' or node_list[0] == 'Cattr':
            tag_name = 'wg'
            tag = node_list[0]
            id = -1
        elif node_list[0][0] == 'Ccoor' or node_list[0] == 'Cattr':
            tag_name = 'wg'
            tag = node_list[0][0]
            id = -1
        else:  
            try:
                tag, id_str = node_list[0].split('{')
            except Exception as e:
                print('Error parsing: ', node_list[0])  
    
        tag_name = 'sentence' if tag == 'S' else 'wg'
        id = int(id_str[:-1]) if id != -1 else -1
        node = create_node(tag, tag_name, id)
        for child_list in node_list[1:]:
            child_node = create_tree(child_list)
            node.append(child_node)
        return node
    else:
        tag_name = 'w'
        tag, id_str = node_list[0].split('{')
        id = int(id_str[:-1])
        return create_node(tag, tag_name, id)

# %%
# Cleanup function to move every node with a 'mother' attribute to the
# node with the matching id. This is necessary because the ETCBC data
# does not necessarily nest these relations, preferring to encode them
# as attributes.

# Note: for many nodes with a mother, the mother node cannot be found based
# on the way I am breaking up sentences, I suspect. It might be worth trying
# to build these trees not based on sentences as the basic unit but based on
# the entire book (more like OpenText 2.0)

def move_node_to_mother(node, element_tree):
    if 'mother' in node.attrib:
        mother_id = node.attrib['mother']
        mother_node = element_tree.find('.//*[@id="{}"]'.format(mother_id))
        if mother_node is not None:
            mother_node.append(node)
        else:
            print('No mother node found for id: ', mother_id, ' Node with mother: ', node.tag, node.attrib['id'])
    # All the children should go along with the passed node
    
def move_nodes_to_mother(element_tree):
    for node in element_tree.iter():
        move_node_to_mother(node, element_tree)

# %% [markdown]
# ## Create XML trees for each chapter

# %%
chapters = [row for row in data.values() if row['otype'] == 'chapter']
verses = [row for row in data.values() if row['otype'] == 'verse']

# %%
book_lookup = {
    'Genesis':'GEN',
    'Exodus':'EXO',
    'Leviticus':'LEV',
    'Numeri':'NUM',
    'Deuteronomium':'DEU',
    'Josua':'JOS',
    'Judices':'JDG',
    'Ruth':'RUT',
    'Samuel_I':'1SA',
    'Samuel_II':'2SA',
    'Reges_I':'1KI',
    'Reges_II':'2KI',
    'Chronica_I':'1CH',
    'Chronica_II':'2CH',
    'Esra':'EZR',
    'Nehemia':'NEH',
    'Esther':'EST',
    'Iob':'JOB',
    'Psalmi':'PSA',
    'Proverbia':'PRO',
    'Ecclesiastes':'ECC',
    'Canticum':'SNG',
    'Jesaia':'ISA',
    'Jeremia':'JER',
    'Threni':'LAM',
    'Ezechiel':'EZK',
    'Daniel':'DAN',
    'Hosea':'HOS',
    'Joel':'JOL',
    'Amos':'AMO',
    'Obadia':'OBA',
    'Jona':'JON',
    'Micha':'MIC',
    'Nahum':'NAM',
    'Habakuk':'HAB',
    'Zephania':'ZEP',
    'Haggai':'HAG',
    'Sacharia':'ZEC',
    'Maleachi':'MAL',
}

# %%
# Assign each sentence to a book and chapter lookup dict
chapter_dict = dict()
for i, sentence in enumerate(sentences):
    treen = sentence['treen']
    # Parse treen brackets into a nested list
    parsed = _parseBrackets(treen)
    chapter = sentence['in.chapter']
    # verse = sentence['in.verse']
    # find chapter in chapters using 'n' field
    ch_row = [row for row in chapters if row['n'] == chapter][0]
    book = book_lookup[ch_row['book']]
    ch_formatted = ' '.join([book, ch_row['chapter']])
    # find verse in verses using 'n' field
    # v_row = [row for row in verses if row['n'] == verse][0]['verse']
    chapter_dict[ch_formatted] = chapter_dict.get(ch_formatted, []) + [parsed[0]]

# %%
# Sanity check
chapter_dict['GEN 1']
# Out:
# [['S{1172308}',
#   ['C{427559}',
#    ['PP{651573}', ['pp{1}'], ['n{2}']],
#    ['VP{651574}', ['vb{3}']],
#    ['NP{651575}', ['n{4}']],
#    ['PP{651576}',
#     ['U{1300539}', ['pp{5}'], ['dt{6}'], ['n{7}']],
#     ['cj{8}'],
#     ['U{1300540}', ['pp{9}'], ['dt{10}'], ['n{11}']]]]],
#  ['S{1172309}',
#   ['C{427560}',
#    ['CP{651577}', ['cj{1}']],
#    ['NP{651578}', ['dt{2}'], ['n{3}']],
#    ['VP{651579}', ['vb{4}']],
#    ['NP{651580}',
#     ['U{1300541}', ['n{5}']],
#     ['cj{6}'],
#     ['U{1300542}', ['n{7}']]]]],
#  ['S{1172310}',
#   ['C{427561}',
#    ['CP{651581}', ['cj{1}']],
#    ['NP{651582}', ['n{2}']],
#    ['PP{651583}',
#     ['pp{3}'],
#     ['U{1300543}', ['n{4}']],
#     ['U{1300544}', ['n{5}']]]]],
#  ['S{1172311}',
#   ['C{427562}',
#    ['CP{651584}', ['cj{1}']],
#    ['NP{651585}', ['U{1300545}', ['n{2}']], ['U{1300546}', ['n{3}']]],
#    ['VP{651586}', ['vb{4}']],
#    ['PP{651587}',
#     ['pp{5}'],
#     ['U{1300547}', ['n{6}']],
#     ['U{1300548}', ['dt{7}'], ['n{8}']]]]],
#  ['S{1172312}',
#   ['C{427563}',
#    ['CP{651588}', ['cj{1}']],
#    ['VP{651589}', ['vb{2}']],
#    ['NP{651590}', ['n{3}']]]],
#  ['S{1172313}',
#   ['C{427564}', ['VP{651591}', ['vb{1}']], ['NP{651592}', ['n{2}']]]],
#  ['S{1172314}',
#   ['C{427565}',
#    ['CP{651593}', ['cj{1}']],
#    ['VP{651594}', ['vb{2}']],
#    ['NP{651595}', ['n{3}']]]],
#  ['S{1172315}',
#   ['C{427566}',
#    ['CP{651596}', ['cj{1}']],
#    ['VP{651597}', ['vb{2}']],
#    ['NP{651598}', ['n{3}']],
#    ['PP{651599}', ['pp{4}'], ['dt{5}'], ['n{6}']],
#    ['Cobjc{427567}', ['CP{651600}', ['cj{7}']], ['VP{651601}', ['vb{8}']]]]],
#  ['S{1172316}',
#   ['C{427568}',
#    ['CP{651602}', ['cj{1}']],
#    ['VP{651603}', ['vb{2}']],
#    ['NP{651604}', ['n{3}']],
#    ['PP{651605}',
#     ['U{1300549}', ['n{4}'], ['dt{5}'], ['n{6}']],
#     ['cj{7}'],
#     ['U{1300550}', ['n{8}'], ['dt{9}'], ['n{10}']]]]],
#  ['S{1172317}',
#   ['C{427569}',
#    ['CP{651606}', ['cj{1}']],
#    ['VP{651607}', ['vb{2}']],
#    ['NP{651608}', ['n{3}']],
#    ['PP{651609}', ['pp{4}'], ['dt{5}'], ['n{6}']],
#    ['NP{651610}', ['n{7}']]]],
#  ['S{1172318}',
#   ['C{427570}',
#    ['CP{651611}', ['cj{1}']],
#    ['PP{651612}', ['pp{2}'], ['dt{3}'], ['n{4}']],
#    ['VP{651613}', ['vb{5}']],
#    ['NP{651614}', ['n{6}']]]],
#  ['S{1172319}',
#   ['C{427571}',
#    ['CP{651615}', ['cj{1}']],
#    ['VP{651616}', ['vb{2}']],
#    ['NP{651617}', ['n{3}']]]],
#  ['S{1172320}',
#   ['C{427572}',
#    ['CP{651618}', ['cj{1}']],
#    ['VP{651619}', ['vb{2}']],
#    ['NP{651620}', ['n{3}']]]],
#  ['S{1172321}',
#   ['C{427573}',
#    ['NP{651621}', ['U{1300551}', ['n{1}']], ['U{1300552}', ['n{2}']]]]],
#  ['S{1172322}',
#   ['C{427574}',
#    ['CP{651622}', ['cj{1}']],
#    ['VP{651623}', ['vb{2}']],
#    ['NP{651624}', ['n{3}']]]],
#  ['S{1172323}',
#   ['C{427575}',
#    ['VP{651625}', ['vb{1}']],
#    ['NP{651626}', ['n{2}']],
#    ['PP{651627}',
#     ['pp{3}'],
#     ['U{1300553}', ['n{4}']],
#     ['U{1300554}', ['dt{5}'], ['n{6}']]]]],
#  ['S{1172324}',
#   ['C{427576}',
#    ['CP{651628}', ['cj{1}']],
#    ['VP{651629}', ['vb{2}']],
#    ['VP{651630}', ['vb{3}']],
#    ['PP{651631}', ['n{4}'], ['n{5}'], ['pp{6}'], ['n{7}']]]],
#  ['S{1172325}',
#   ['C{427577}',
#    ['CP{651632}', ['cj{1}']],
#    ['VP{651633}', ['vb{2}']],
#    ['NP{651634}', ['n{3}']],
#    ['PP{651635}', ['pp{4}'], ['dt{5}'], ['n{6}']]]],
#  ['S{1172326}',
#   ['C{427578}',
#    ['CP{651636}', ['cj{1}']],
#    ['VP{651637}', ['vb{2}']],
#    ['PP{651638}',
#     ['n{3}'],
#     ['dt{4}'],
#     ['n{5}'],
#     ['Cattr{427579}',
#      ['CP{651639}', ['cj{6}']],
#      ['PP{651640}', ['pp{7}'], ['n{8}'], ['pp{9}'], ['dt{10}'], ['n{11}']]],
#     ['cj{12}'],
#     ['n{13}'],
#     ['dt{14}'],
#     ['n{15}'],
#     ['Cattr{427580}',
#      ['CP{651641}', ['cj{16}']],
#      ['PP{651642}',
#       ['pp{17}'],
#       ['pp{18}'],
#       ['pp{19}'],
#       ['dt{20}'],
#       ['n{21}']]]]]],
#  ['S{1172327}',
#   ['C{427581}',
#    ['CP{651643}', ['cj{1}']],
#    ['VP{651644}', ['vb{2}']],
#    ['AdvP{651645}', ['av{3}']]]],
#  ['S{1172328}',
#   ['C{427582}',
#    ['CP{651646}', ['cj{1}']],
#    ['VP{651647}', ['vb{2}']],
#    ['NP{651648}', ['n{3}']],
#    ['PP{651649}', ['pp{4}'], ['dt{5}'], ['n{6}']],
#    ['NP{651650}', ['n{7}']]]],
#  ['S{1172329}',
#   ['C{427583}',
#    ['CP{651651}', ['cj{1}']],
#    ['VP{651652}', ['vb{2}']],
#    ['NP{651653}', ['n{3}']]]],
#  ['S{1172330}',
#   ['C{427584}',
#    ['CP{651654}', ['cj{1}']],
#    ['VP{651655}', ['vb{2}']],
#    ['NP{651656}', ['n{3}']]]],
#  ['S{1172331}',
#   ['C{427585}',
#    ['NP{651657}', ['U{1300555}', ['n{1}']], ['U{1300556}', ['aj{2}']]]]],
#  ['S{1172332}',
#   ['C{427586}',
#    ['CP{651658}', ['cj{1}']],
#    ['VP{651659}', ['vb{2}']],
#    ['NP{651660}', ['n{3}']]]],
#  ['S{1172333}',
#   ['C{427587}',
#    ['VP{651661}', ['vb{1}']],
#    ['NP{651662}',
#     ['dt{2}'],
#     ['n{3}'],
#     ['pp{4}'],
#     ['U{1300557}', ['n{5}']],
#     ['U{1300558}', ['dt{6}'], ['n{7}']]],
#    ['PP{651663}',
#     ['pp{8}'],
#     ['U{1300559}', ['n{9}']],
#     ['U{1300560}', ['n{10}']]]]],
#  ['S{1172334}',
#   ['C{427588}',
#    ['CP{651664}', ['cj{1}']],
#    ['VP{651665}', ['vb{2}']],
#    ['NP{651666}', ['dt{3}'], ['n{4}']]]],
#  ['S{1172335}',
#   ['C{427589}',
#    ['CP{651667}', ['cj{1}']],
#    ['VP{651668}', ['vb{2}']],
#    ['AdvP{651669}', ['av{3}']]]],
#  ['S{1172336}',
#   ['C{427590}',
#    ['CP{651670}', ['cj{1}']],
#    ['VP{651671}', ['vb{2}']],
#    ['NP{651672}', ['n{3}']],
#    ['PP{651673}', ['pp{4}'], ['dt{5}'], ['n{6}']],
#    ['NP{651674}', ['n{7}']]]],
#  ['S{1172337}',
#   ['C{427591}',
#    ['CP{651675}', ['cj{1}']],
#    ['PP{651676}',
#     ['pp{2}'],
#     ['U{1300561}', ['n{3}']],
#     ['U{1300562}', ['dt{4}'], ['n{5}']]],
#    ['VP{651677}', ['vb{6}']],
#    ['NP{651678}', ['n{7}']]]],
#  ['S{1172338}',
#   ['C{427592}',
#    ['CP{651679}', ['cj{1}']],
#    ['VP{651680}', ['vb{2}']],
#    ['NP{651681}', ['n{3}']],
#    ['Cobjc{427593}', ['CP{651682}', ['cj{4}']], ['VP{651683}', ['vb{5}']]]]],
#  ['S{1172339}',
#   ['C{427594}',
#    ['CP{651684}', ['cj{1}']],
#    ['VP{651685}', ['vb{2}']],
#    ['NP{651686}', ['n{3}']]]],
#  ['S{1172340}',
#   ['C{427595}',
#    ['VP{651687}', ['vb{1}']],
#    ['NP{651688}', ['dt{2}'], ['n{3}']],
#    ['NP{651689}',
#     ['n{4}'],
#     ['n{5}'],
#     ['Cattr{427596}', ['VP{651690}', ['vb{6}']], ['NP{651691}', ['n{7}']]],
#     ['U{1300563}', ['n{8}']],
#     ['U{1300564}', ['n{9}']],
#     ['Cattr{427597}',
#      ['VP{651692}', ['vb{10}']],
#      ['NP{651693}',
#       ['n{11}'],
#       ['Cattr{427598}',
#        ['CP{651695}', ['cj{14}']],
#        ['NP{651696}', ['n{15}']],
#        ['PP{651697}', ['pp{16}']]]],
#      ['PP{651694}', ['pp{12}'], ['n{13}']],
#      ['PP{651698}', ['pp{17}'], ['dt{18}'], ['n{19}']]]]]],
#  ['S{1172341}',
#   ['C{427599}',
#    ['CP{651699}', ['cj{1}']],
#    ['VP{651700}', ['vb{2}']],
#    ['AdvP{651701}', ['av{3}']]]],
#  ['S{1172342}',
#   ['C{427600}',
#    ['CP{651702}', ['cj{1}']],
#    ['VP{651703}', ['vb{2}']],
#    ['NP{651704}', ['dt{3}'], ['n{4}']],
#    ['NP{651705}',
#     ['n{5}'],
#     ['n{6}'],
#     ['Cattr{427601}',
#      ['VP{651706}', ['vb{7}']],
#      ['NP{651707}', ['n{8}']],
#      ['PP{651708}', ['pp{9}'], ['n{10}']]],
#     ['cj{11}'],
#     ['n{12}'],
#     ['Cattr{427602}',
#      ['VP{651709}', ['vb{13}']],
#      ['NP{651710}',
#       ['n{14}'],
#       ['Cattr{427603}',
#        ['CP{651711}', ['cj{15}']],
#        ['NP{651712}', ['n{16}']],
#        ['PP{651713}', ['pp{17}']]]],
#      ['PP{651714}', ['pp{18}'], ['n{19}']]]]]],
#  ['S{1172343}',
#   ['C{427604}',
#    ['CP{651715}', ['cj{1}']],
#    ['VP{651716}', ['vb{2}']],
#    ['NP{651717}', ['n{3}']],
#    ['Cobjc{427605}', ['CP{651718}', ['cj{4}']], ['VP{651719}', ['vb{5}']]]]],
#  ['S{1172344}',
#   ['C{427606}',
#    ['CP{651720}', ['cj{1}']],
#    ['VP{651721}', ['vb{2}']],
#    ['NP{651722}', ['n{3}']]]],
#  ['S{1172345}',
#   ['C{427607}',
#    ['CP{651723}', ['cj{1}']],
#    ['VP{651724}', ['vb{2}']],
#    ['NP{651725}', ['n{3}']]]],
#  ['S{1172346}',
#   ['C{427608}',
#    ['NP{651726}', ['U{1300565}', ['n{1}']], ['U{1300566}', ['aj{2}']]]]],
#  ['S{1172347}',
#   ['C{427609}',
#    ['CP{651727}', ['cj{1}']],
#    ['VP{651728}', ['vb{2}']],
#    ['NP{651729}', ['n{3}']]]],
#  ['S{1172348}',
#   ['C{427610}',
#    ['VP{651730}', ['vb{1}']],
#    ['NP{651731}', ['n{2}']],
#    ['PP{651732}',
#     ['pp{3}'],
#     ['U{1300567}', ['n{4}']],
#     ['U{1300568}', ['dt{5}'], ['n{6}']]],
#    ['Cadju{427611}',
#     ['VP{651733}', ['pp{7}'], ['vb{8}']],
#     ['PP{651734}',
#      ['U{1300569}', ['n{9}'], ['dt{10}'], ['n{11}']],
#      ['cj{12}'],
#      ['U{1300570}', ['n{13}'], ['dt{14}'], ['n{15}']]]]]],
#  ['S{1172349}',
#   ['C{427612}',
#    ['CP{651735}', ['cj{1}']],
#    ['VP{651736}', ['vb{2}']],
#    ['PP{651737}',
#     ['U{1300573}',
#      ['U{1300571}', ['pp{3}'], ['n{4}']],
#      ['cj{5}'],
#      ['U{1300572}', ['pp{6}'], ['n{7}']]],
#     ['cj{8}'],
#     ['U{1300576}',
#      ['pp{9}'],
#      ['U{1300574}', ['n{10}']],
#      ['cj{11}'],
#      ['U{1300575}', ['n{12}']]]]]],
#  ['S{1172350}',
#   ['C{427613}',
#    ['CP{651738}', ['cj{1}']],
#    ['VP{651739}', ['vb{2}']],
#    ['PP{651740}', ['pp{3}'], ['n{4}']],
#    ['PP{651741}',
#     ['pp{5}'],
#     ['U{1300577}', ['n{6}']],
#     ['U{1300578}', ['dt{7}'], ['n{8}']]],
#    ['Cadju{427614}',
#     ['VP{651742}', ['pp{9}'], ['vb{10}']],
#     ['PP{651743}', ['pp{11}'], ['dt{12}'], ['n{13}']]]]],
#  ['S{1172351}',
#   ['C{427615}',
#    ['CP{651744}', ['cj{1}']],
#    ['VP{651745}', ['vb{2}']],
#    ['AdvP{651746}', ['av{3}']]]],
#  ['S{1172352}',
#   ['C{427616}',
#    ['CP{651747}', ['cj{1}']],
#    ['VP{651748}', ['vb{2}']],
#    ['NP{651749}', ['n{3}']],
#    ['PP{651750}',
#     ['pp{4}'],
#     ['U{1300579}', ['n{5}']],
#     ['U{1300582}',
#      ['U{1300580}', ['dt{6}'], ['n{7}']],
#      ['U{1300581}', ['dt{8}'], ['aj{9}']]],
#     ['pp{10}'],
#     ['U{1300583}', ['dt{11}'], ['n{12}']],
#     ['U{1300584}', ['dt{13}'], ['aj{14}']],
#     ['pp{15}'],
#     ['U{1300585}', ['n{16}']],
#     ['U{1300586}', ['dt{17}'], ['n{18}']],
#     ['cj{19}'],
#     ['pp{20}'],
#     ['U{1300587}', ['dt{21}'], ['n{22}']],
#     ['U{1300588}', ['dt{23}'], ['aj{24}']],
#     ['pp{25}'],
#     ['U{1300589}', ['n{26}']],
#     ['U{1300590}', ['dt{27}'], ['n{28}']],
#     ['cj{29}'],
#     ['pp{30}'],
#     ['dt{31}'],
#     ['n{32}']]]],
#  ['S{1172353}',
#   ['C{427617}',
#    ['CP{651751}', ['cj{1}']],
#    ['VP{651752}', ['vb{2}']],
#    ['PP{651753}', ['pp{3}']],
#    ['NP{651754}', ['n{4}']],
#    ['PP{651755}',
#     ['pp{5}'],
#     ['U{1300591}', ['n{6}']],
#     ['U{1300592}', ['dt{7}'], ['n{8}']]],
#    ['Cadju{427618}',
#     ['Ccoor',
#      ['VP{651756}', ['pp{9}'], ['vb{10}']],
#      ['PP{651757}', ['pp{11}'], ['dt{12}'], ['n{13}']]],
#     ['Ccoor{427619}',
#      ['CP{651758}', ['cj{14}']],
#      ['VP{651759}', ['pp{15}'], ['vb{16}']],
#      ['PP{651760}',
#       ['U{1300593}', ['pp{17}'], ['dt{18}'], ['n{19}']],
#       ['cj{20}'],
#       ['U{1300594}', ['pp{21}'], ['dt{22}'], ['n{23}']]]],
#     ['Ccoor{427620}',
#      ['CP{651761}', ['cj{24}']],
#      ['VP{651762}', ['pp{25}'], ['vb{26}']],
#      ['PP{651763}',
#       ['U{1300595}', ['n{27}'], ['dt{28}'], ['n{29}']],
#       ['cj{30}'],
#       ['U{1300596}', ['n{31}'], ['dt{32}'], ['n{33}']]]]]]],
#  ['S{1172354}',
#   ['C{427621}',
#    ['CP{651764}', ['cj{1}']],
#    ['VP{651765}', ['vb{2}']],
#    ['NP{651766}', ['n{3}']],
#    ['Cobjc{427622}', ['CP{651767}', ['cj{4}']], ['VP{651768}', ['vb{5}']]]]],
#  ['S{1172355}',
#   ['C{427623}',
#    ['CP{651769}', ['cj{1}']],
#    ['VP{651770}', ['vb{2}']],
#    ['NP{651771}', ['n{3}']]]],
#  ['S{1172356}',
#   ['C{427624}',
#    ['CP{651772}', ['cj{1}']],
#    ['VP{651773}', ['vb{2}']],
#    ['NP{651774}', ['n{3}']]]],
#  ['S{1172357}',
#   ['C{427625}',
#    ['NP{651775}', ['U{1300597}', ['n{1}']], ['U{1300598}', ['aj{2}']]]]],
#  ['S{1172358}',
#   ['C{427626}',
#    ['CP{651776}', ['cj{1}']],
#    ['VP{651777}', ['vb{2}']],
#    ['NP{651778}', ['n{3}']]]],
#  ['S{1172359}',
#   ['C{427627}',
#    ['VP{651779}', ['vb{1}']],
#    ['NP{651780}', ['dt{2}'], ['n{3}']],
#    ['NP{651781}',
#     ['U{1300599}', ['n{4}']],
#     ['U{1300602}', ['U{1300600}', ['n{5}']], ['U{1300601}', ['aj{6}']]]]]],
#  ['S{1172360}',
#   ['C{427628}',
#    ['CP{651782}', ['cj{1}']],
#    ['NP{651783}', ['n{2}']],
#    ['VP{651784}', ['vb{3}']],
#    ['PP{651785}',
#     ['pp{4}'],
#     ['dt{5}'],
#     ['n{6}'],
#     ['pp{7}'],
#     ['U{1300603}', ['n{8}']],
#     ['U{1300606}',
#      ['U{1300604}', ['n{9}']],
#      ['U{1300605}', ['dt{10}'], ['n{11}']]]]]],
#  ['S{1172361}',
#   ['C{427629}',
#    ['CP{651786}', ['cj{1}']],
#    ['VP{651787}', ['vb{2}']],
#    ['NP{651788}', ['n{3}']],
#    ['PP{651789}',
#     ['U{1300609}',
#      ['pp{4}'],
#      ['U{1300607}', ['dt{5}'], ['n{6}']],
#      ['U{1300608}', ['dt{7}'], ['aj{8}']]],
#     ['cj{9}'],
#     ['U{1300612}',
#      ['pp{10}'],
#      ['U{1300610}', ['n{11}']],
#      ['U{1300611}',
#       ['n{12}'],
#       ['Cattr{427630}',
#        ['CP{651790}', ['dt{13}']],
#        ['AdjP{651791}', ['aj{14}']]]]],
#     ['Cattr{427631}', ['CP{651792}', ['dt{15}']], ['VP{651793}', ['vb{16}']]],
#     ['Cattr{427632}',
#      ['CP{651794}', ['cj{17}']],
#      ['VP{651795}', ['vb{18}']],
#      ['NP{651796}', ['dt{19}'], ['n{20}']]]],
#    ['PP{651797}', ['pp{21}'], ['n{22}']]],
#   ['C{427633}',
#    ['CP{651798}', ['cj{23}']],
#    ['PP{651799}',
#     ['pp{24}'],
#     ['U{1300613}', ['n{25}']],
#     ['U{1300616}', ['U{1300614}', ['n{26}']], ['U{1300615}', ['n{27}']]]],
#    ['PP{651800}', ['pp{28}'], ['n{29}']]]],
#  ['S{1172362}',
#   ['C{427634}',
#    ['CP{651801}', ['cj{1}']],
#    ['VP{651802}', ['vb{2}']],
#    ['NP{651803}', ['n{3}']],
#    ['Cobjc{427635}', ['CP{651804}', ['cj{4}']], ['VP{651805}', ['vb{5}']]]]],
#  ['S{1172363}',
#   ['C{427636}',
#    ['CP{651806}', ['cj{1}']],
#    ['VP{651807}', ['vb{2}']],
#    ['PP{651808}', ['pp{3}']],
#    ['NP{651809}', ['n{4}']],
#    ['Cadju{427637}', ['VP{651810}', ['pp{5}'], ['vb{6}']]]]],
#  ['S{1172364}', ['C{427638}', ['VP{651811}', ['vb{1}']]]],
#  ['S{1172365}',
#   ['C{427639}', ['CP{651812}', ['cj{1}']], ['VP{651813}', ['vb{2}']]]],
#  ['S{1172366}',
#   ['C{427640}',
#    ['CP{651814}', ['cj{1}']],
#    ['VP{651815}', ['vb{2}']],
#    ['PP{651816}',
#     ['pp{3}'],
#     ['dt{4}'],
#     ['n{5}'],
#     ['pp{6}'],
#     ['dt{7}'],
#     ['n{8}']]]],
#  ['S{1172367}',
#   ['C{427641}',
#    ['CP{651817}', ['cj{1}']],
#    ['NP{651818}', ['dt{2}'], ['n{3}']],
#    ['VP{651819}', ['vb{4}']],
#    ['PP{651820}', ['pp{5}'], ['dt{6}'], ['n{7}']]]],
#  ['S{1172368}',
#   ['C{427642}',
#    ['CP{651821}', ['cj{1}']],
#    ['VP{651822}', ['vb{2}']],
#    ['NP{651823}', ['n{3}']]]],
#  ['S{1172369}',
#   ['C{427643}',
#    ['CP{651824}', ['cj{1}']],
#    ['VP{651825}', ['vb{2}']],
#    ['NP{651826}', ['n{3}']]]],
#  ['S{1172370}',
#   ['C{427644}',
#    ['NP{651827}', ['U{1300617}', ['n{1}']], ['U{1300618}', ['aj{2}']]]]],
#  ['S{1172371}',
#   ['C{427645}',
#    ['CP{651828}', ['cj{1}']],
#    ['VP{651829}', ['vb{2}']],
#    ['NP{651830}', ['n{3}']]]],
#  ['S{1172372}',
#   ['C{427646}',
#    ['VP{651831}', ['vb{1}']],
#    ['NP{651832}', ['dt{2}'], ['n{3}']],
#    ['NP{651833}', ['U{1300619}', ['n{4}']], ['U{1300620}', ['aj{5}']]],
#    ['PP{651834}', ['pp{6}'], ['n{7}']]],
#   ['C{427647}',
#    ['NP{651835}',
#     ['U{1300623}',
#      ['U{1300621}', ['n{8}']],
#      ['cj{9}'],
#      ['U{1300622}', ['n{10}']]],
#     ['cj{11}'],
#     ['U{1300626}', ['U{1300624}', ['n{12}']], ['U{1300625}', ['n{13}']]]],
#    ['PP{651836}', ['pp{14}'], ['n{15}']]]],
#  ['S{1172373}',
#   ['C{427648}',
#    ['CP{651837}', ['cj{1}']],
#    ['VP{651838}', ['vb{2}']],
#    ['AdvP{651839}', ['av{3}']]]],
#  ['S{1172374}',
#   ['C{427649}',
#    ['CP{651840}', ['cj{1}']],
#    ['VP{651841}', ['vb{2}']],
#    ['NP{651842}', ['n{3}']],
#    ['PP{651843}',
#     ['pp{4}'],
#     ['U{1300627}', ['n{5}']],
#     ['U{1300628}', ['dt{6}'], ['n{7}']]],
#    ['PP{651844}', ['pp{8}'], ['n{9}']]],
#   ['C{427650}',
#    ['CP{651845}', ['cj{10}']],
#    ['PP{651846}', ['pp{11}'], ['dt{12}'], ['n{13}']],
#    ['PP{651847}', ['pp{14}'], ['n{15}']]],
#   ['C{427651}',
#    ['CP{651848}', ['cj{16}']],
#    ['PP{651849}',
#     ['pp{17}'],
#     ['U{1300629}', ['n{18}']],
#     ['U{1300632}',
#      ['U{1300630}', ['n{19}']],
#      ['U{1300631}', ['dt{20}'], ['n{21}']]]],
#    ['PP{651850}', ['pp{22}'], ['n{23}']]]],
#  ['S{1172375}',
#   ['C{427652}',
#    ['CP{651851}', ['cj{1}']],
#    ['VP{651852}', ['vb{2}']],
#    ['NP{651853}', ['n{3}']],
#    ['Cobjc{427653}', ['CP{651854}', ['cj{4}']], ['VP{651855}', ['vb{5}']]]]],
#  ['S{1172376}',
#   ['C{427654}',
#    ['CP{651856}', ['cj{1}']],
#    ['VP{651857}', ['vb{2}']],
#    ['NP{651858}', ['n{3}']]]],
#  ['S{1172377}',
#   ['C{427655}',
#    ['VP{651859}', ['vb{1}']],
#    ['NP{651860}', ['n{2}']],
#    ['PP{651861}', ['pp{3}'], ['n{4}']],
#    ['PP{651862}', ['pp{5}'], ['n{6}']]]],
#  ['S{1172378}',
#   ['C{427656}',
#    ['CP{651863}', ['cj{1}']],
#    ['VP{651864}', ['vb{2}']],
#    ['PP{651865}',
#     ['U{1300639}',
#      ['U{1300635}',
#       ['pp{3}'],
#       ['U{1300633}', ['n{4}']],
#       ['U{1300634}', ['dt{5}'], ['n{6}']]],
#      ['cj{7}'],
#      ['U{1300638}',
#       ['pp{8}'],
#       ['U{1300636}', ['n{9}']],
#       ['U{1300637}', ['dt{10}'], ['n{11}']]]],
#     ['cj{12}'],
#     ['U{1300644}',
#      ['U{1300640}', ['pp{13}'], ['dt{14}'], ['n{15}']],
#      ['cj{16}'],
#      ['U{1300643}',
#       ['pp{17}'],
#       ['U{1300641}', ['n{18}']],
#       ['U{1300642}', ['dt{19}'], ['n{20}']]]],
#     ['cj{21}'],
#     ['pp{22}'],
#     ['U{1300645}', ['n{23}']],
#     ['U{1300646}',
#      ['dt{24}'],
#      ['n{25}'],
#      ['Cattr{427657}',
#       ['CP{651866}', ['dt{26}']],
#       ['VP{651867}', ['vb{27}']],
#       ['PP{651868}', ['pp{28}'], ['dt{29}'], ['n{30}']]]]]]],
#  ['S{1172379}',
#   ['C{427658}',
#    ['CP{651869}', ['cj{1}']],
#    ['VP{651870}', ['vb{2}']],
#    ['NP{651871}', ['n{3}']],
#    ['PP{651872}', ['pp{4}'], ['dt{5}'], ['n{6}']],
#    ['PP{651873}', ['pp{7}'], ['n{8}']]]],
#  ['S{1172380}',
#   ['C{427659}',
#    ['PP{651874}',
#     ['pp{1}'],
#     ['U{1300647}', ['n{2}']],
#     ['U{1300648}', ['n{3}']]],
#    ['VP{651875}', ['vb{4}']],
#    ['PP{651876}', ['pp{5}']]]],
#  ['S{1172381}',
#   ['C{427660}',
#    ['NP{651877}',
#     ['U{1300649}', ['aj{1}']],
#     ['cj{2}'],
#     ['U{1300650}', ['n{3}']]],
#    ['VP{651878}', ['vb{4}']],
#    ['PP{651879}', ['pp{5}']]]],
#  ['S{1172382}',
#   ['C{427661}',
#    ['CP{651880}', ['cj{1}']],
#    ['VP{651881}', ['vb{2}']],
#    ['PP{651882}', ['pp{3}']],
#    ['NP{651883}', ['n{4}']]]],
#  ['S{1172383}',
#   ['C{427662}',
#    ['CP{651884}', ['cj{1}']],
#    ['VP{651885}', ['vb{2}']],
#    ['PP{651886}', ['pp{3}']],
#    ['NP{651887}', ['n{4}']]]],
#  ['S{1172384}', ['C{427663}', ['VP{651888}', ['vb{1}']]]],
#  ['S{1172385}',
#   ['C{427664}', ['CP{651889}', ['cj{1}']], ['VP{651890}', ['vb{2}']]]],
#  ['S{1172386}',
#   ['C{427665}',
#    ['CP{651891}', ['cj{1}']],
#    ['VP{651892}', ['vb{2}']],
#    ['PP{651893}', ['pp{3}'], ['dt{4}'], ['n{5}']]]],
#  ['S{1172387}',
#   ['C{427666}', ['CP{651894}', ['cj{1}']], ['VP{651895}', ['vb{2}']]]],
#  ['S{1172388}',
#   ['C{427667}',
#    ['CP{651896}', ['cj{1}']],
#    ['VP{651897}', ['vb{2}']],
#    ['PP{651898}',
#     ['U{1300657}',
#      ['U{1300653}',
#       ['pp{3}'],
#       ['U{1300651}', ['n{4}']],
#       ['U{1300652}', ['dt{5}'], ['n{6}']]],
#      ['cj{7}'],
#      ['U{1300656}',
#       ['pp{8}'],
#       ['U{1300654}', ['n{9}']],
#       ['U{1300655}', ['dt{10}'], ['n{11}']]]],
#     ['cj{12}'],
#     ['U{1300660}',
#      ['pp{13}'],
#      ['U{1300658}', ['n{14}']],
#      ['U{1300659}',
#       ['n{15}'],
#       ['Cattr{427668}',
#        ['CP{651899}', ['dt{16}']],
#        ['VP{651900}', ['vb{17}']],
#        ['PP{651901}', ['pp{18}'], ['dt{19}'], ['n{20}']]]]]]]],
#  ['S{1172389}',
#   ['C{427669}',
#    ['CP{651902}', ['cj{1}']],
#    ['VP{651903}', ['vb{2}']],
#    ['NP{651904}', ['n{3}']]]],
#  ['S{1172390}',
#   ['C{427670}',
#    ['InjP{651905}', ['ij{1}']],
#    ['VP{651906}', ['vb{2}']],
#    ['PP{651907}', ['pp{3}']],
#    ['PP{651908}',
#     ['pp{4}'],
#     ['U{1300661}', ['n{5}']],
#     ['U{1300662}', ['n{6}']],
#     ['Cattr{427671}', ['VP{651909}', ['vb{7}']], ['NP{651910}', ['n{8}']]],
#     ['Cattr{427672}',
#      ['CP{651911}', ['cj{9}']],
#      ['PP{651912}',
#       ['pp{10}'],
#       ['U{1300663}', ['n{11}']],
#       ['U{1300666}',
#        ['U{1300664}', ['n{12}']],
#        ['U{1300665}', ['dt{13}'], ['n{14}']]]]],
#     ['cj{15}'],
#     ['pp{16}'],
#     ['U{1300667}', ['n{17}']],
#     ['U{1300668}', ['dt{18}'], ['n{19}']],
#     ['Cattr{427673}',
#      ['CP{651913}', ['cj{20}']],
#      ['PP{651914}', ['pp{21}']],
#      ['NP{651915}',
#       ['U{1300669}', ['n{22}']],
#       ['U{1300670}', ['n{23}']],
#       ['Cattr{427674}',
#        ['VP{651916}', ['vb{24}']],
#        ['NP{651917}', ['n{25}']]]]]]],
#   ['C{427676}',
#    ['CP{651921}', ['cj{30}']],
#    ['PP{651922}',
#     ['U{1300675}',
#      ['pp{31}'],
#      ['U{1300671}', ['n{32}']],
#      ['U{1300674}',
#       ['U{1300672}', ['n{33}']],
#       ['U{1300673}', ['dt{34}'], ['n{35}']]]],
#     ['cj{36}'],
#     ['U{1300680}',
#      ['pp{37}'],
#      ['U{1300676}', ['n{38}']],
#      ['U{1300679}',
#       ['U{1300677}', ['n{39}']],
#       ['U{1300678}', ['dt{40}'], ['n{41}']]]],
#     ['cj{42}'],
#     ['pp{43}'],
#     ['U{1300681}', ['n{44}']],
#     ['U{1300682}',
#      ['vb{45}'],
#      ['Cattr{427677}',
#       ['CP{651923}', ['cj{49}']],
#       ['PP{651924}', ['pp{50}']],
#       ['NP{651925}', ['U{1300683}', ['n{51}']], ['U{1300684}', ['aj{52}']]]]],
#     ['pp{46}'],
#     ['dt{47}'],
#     ['n{48}']],
#    ['PP{651926}',
#     ['pp{53}'],
#     ['U{1300685}', ['n{54}']],
#     ['U{1300688}', ['U{1300686}', ['n{55}']], ['U{1300687}', ['n{56}']]]],
#    ['PP{651927}', ['pp{57}'], ['n{58}']]]],
#  ['S{1172391}',
#   ['C{427675}',
#    ['PP{651918}', ['pp{1}']],
#    ['VP{651919}', ['vb{2}']],
#    ['PP{651920}', ['pp{3}'], ['n{4}']]]],
#  ['S{1172392}',
#   ['C{427678}',
#    ['CP{651928}', ['cj{1}']],
#    ['VP{651929}', ['vb{2}']],
#    ['AdvP{651930}', ['av{3}']]]],
#  ['S{1172393}',
#   ['C{427679}',
#    ['CP{651931}', ['cj{1}']],
#    ['VP{651932}', ['vb{2}']],
#    ['NP{651933}', ['n{3}']],
#    ['PP{651934}',
#     ['pp{4}'],
#     ['n{5}'],
#     ['Crgrc{427680}', ['CP{651935}', ['cj{6}']], ['VP{651936}', ['vb{7}']]]]]],
#  ['S{1172394}',
#   ['C{427681}',
#    ['CP{651937}', ['cj{1}']],
#    ['InjP{651938}', ['ij{2}']],
#    ['AdjP{651939}', ['aj{3}']],
#    ['AdvP{651940}', ['n{4}']]]],
#  ['S{1172395}',
#   ['C{427682}',
#    ['CP{651941}', ['cj{1}']],
#    ['VP{651942}', ['vb{2}']],
#    ['NP{651943}', ['n{3}']]]],
#  ['S{1172396}',
#   ['C{427683}',
#    ['CP{651944}', ['cj{1}']],
#    ['VP{651945}', ['vb{2}']],
#    ['NP{651946}', ['n{3}']]]],
#  ['S{1172397}',
#   ['C{427684}',
#    ['NP{651947}',
#     ['U{1300689}', ['n{1}']],
#     ['U{1300690}', ['dt{2}'], ['aj{3}']]]]]]

# %%
# # Parse each sentence's brackets
# parsed_sentences = []
# for i, sentence in enumerate(sentences):
#     treen = sentence['treen']
#     # Parse treen brackets into a nested list
#     parsed = _parseBrackets(treen)
#     parsed_sentences.append(parsed[0])
#     # print(i, parsed[0])

# %%
# Enumerate book names
bb = [
    'GEN',
'EXO',
'LEV',
'NUM',
'DEU',
'JOS',
'JDG',
'RUT',
'1SA',
'2SA',
'1KI',
'2KI',
'1CH',
'2CH',
'EZR',
'NEH',
'EST',
'JOB',
'PSA',
'PRO',
'ECC',
'SNG',
'ISA',
'JER',
'LAM',
'EZK',
'DAN',
'HOS',
'JOL',
'AMO',
'OBA',
'JON',
'MIC',
'NAM',
'HAB',
'ZEP',
'HAG',
'ZEC',
'MAL',
]
enumerated_books = dict()
for i, book in enumerate(bb):
    j = i + 1
    enumerated_books[book] = f'{j:02d}'

# %%
# Create XML tree

for chapter, sentences in chapter_dict.items():
    root = etree.Element('root')    
    for sentence in sentences:
        root.append(create_tree(sentence))
    
    # Optionally, add a stylesheet to the XML
    root.addprevious(etree.PI('xml-stylesheet', 'href="treedown.css"'))
    
    # Save XML
    tree = etree.ElementTree(root)
    
    ## NOTE: ##
    # Restructure tree. Involves reordering nodes, so comment this line if you want a tree with words in canonical order
    move_nodes_to_mother(tree) 
    
    str_tree = etree.tostring(tree, pretty_print=True, encoding='unicode') #.decode('unicode')
    
    # example name: 28-HOS-009.xml
    book, ch_num = chapter.split(' ')
    save_path = 'xml/chapters/{}-{}-{:03d}.xml'.format(enumerated_books[book], book, int(ch_num))
    # save_path = '~/github/etcbc/bhsa/_temp/2017/r/bhsa2017_trunc.xml'
    with(open(save_path, 'w', encoding='utf-8')) as f:
        f.write(str_tree)
# Out:
# No mother node found for id:  307  Node with mother:  wg 1300590
# No mother node found for id:  319  Node with mother:  wg 1300592
# No mother node found for id:  366  Node with mother:  wg 1300602
# No mother node found for id:  376  Node with mother:  wg 1300606
# No mother node found for id:  377  Node with mother:  wg 1300605
# No mother node found for id:  390  Node with mother:  wg 1300611
# No mother node found for id:  391  Node with mother:  wg 427630
# No mother node found for id:  404  Node with mother:  wg 1300616
# No mother node found for id:  460  Node with mother:  wg 1300625
# No mother node found for id:  471  Node with mother:  wg 1300628
# No mother node found for id:  484  Node with mother:  wg 1300632
# No mother node found for id:  485  Node with mother:  wg 1300631
# No mother node found for id:  507  Node with mother:  wg 1300634
# No mother node found for id:  512  Node with mother:  wg 1300637
# No mother node found for id:  521  Node with mother:  wg 1300642
# No mother node found for id:  526  Node with mother:  wg 1300646
# No mother node found for id:  528  Node with mother:  wg 427657
# No mother node found for id:  543  Node with mother:  wg 1300648
# No mother node found for id:  573  Node with mother:  wg 1300652
# No mother node found for id:  578  Node with mother:  wg 1300655
# No mother node found for id:  583  Node with mother:  wg 1300659
# No mother node found for id:  584  Node with mother:  wg 427668
# No mother node found for id:  597  Node with mother:  wg 1300662
# No mother node found for id:  624  Node with mother:  wg 1300674
# No mother node found for id:  625  Node with mother:  wg 1300673
# No mother node found for id:  630  Node with mother:  wg 1300679
# No mother node found for id:  631  Node with mother:  wg 1300678
# No mother node found for id:  636  Node with mother:  wg 1300682
# No mother node found for id:  637  Node with mother:  wg 427677
# No mother node found for id:  646  Node with mother:  wg 1300688
# No mother node found for id:  658  Node with mother:  wg 427680
# No mother node found for id:  671  Node with mother:  wg 1300690
# No mother node found for id:  682  Node with mother:  wg 1300695
# No mother node found for id:  703  Node with mother:  wg 1300702
# No mother node found for id:  711  Node with mother:  wg 1300704
# No mother node found for id:  721  Node with mother:  wg 1300706
# No mother node found for id:  729  Node with mother:  wg 1300710
# No mother node found for id:  738  Node with mother:  wg 427698
# No mother node found for id:  746  Node with mother:  wg 1300718
# No mother node found for id:  747  Node with mother:  wg 1300717
# No mother node found for id:  756  Node with mother:  wg 1300722
# No mother node found for id:  757  Node with mother:  wg 1300721
# No mother node found for id:  787  Node with mother:  wg 1300728
# No mother node found for id:  788  Node with mother:  wg 1300727
# No mother node found for id:  806  Node with mother:  wg 1300732
# No mother node found for id:  839  Node with mother:  wg 1300740
# No mother node found for id:  849  Node with mother:  wg 1300742
# No mother node found for id:  853  Node with mother:  wg 1300744
# No mother node found for id:  857  Node with mother:  wg 1300746
# No mother node found for id:  882  Node with mother:  wg 1300754
# No mother node found for id:  890  Node with mother:  wg 1300758
# No mother node found for id:  891  Node with mother:  wg 1300757
# No mother node found for id:  899  Node with mother:  wg 1300762
# No mother node found for id:  909  Node with mother:  wg 1300765
# No mother node found for id:  913  Node with mother:  wg 1300770
# No mother node found for id:  923  Node with mother:  wg 1300774
# No mother node found for id:  924  Node with mother:  wg 1300773
# No mother node found for id:  927  Node with mother:  wg 1300778
# No mother node found for id:  955  Node with mother:  wg 1300784
# No mother node found for id:  972  Node with mother:  wg 1300790
# No mother node found for id:  973  Node with mother:  wg 1300789
# No mother node found for id:  980  Node with mother:  wg 1300792
# No mother node found for id:  991  Node with mother:  wg 427745
# No mother node found for id:  1019  Node with mother:  wg 1300804
# No mother node found for id:  1020  Node with mother:  wg 1300803
# No mother node found for id:  1025  Node with mother:  wg 1300809
# No mother node found for id:  1026  Node with mother:  wg 1300808
# No mother node found for id:  1040  Node with mother:  wg 427755
# No mother node found for id:  1056  Node with mother:  wg 1300814
# No mother node found for id:  1061  Node with mother:  wg 1300817
# No mother node found for id:  1066  Node with mother:  wg 1300823
# No mother node found for id:  1067  Node with mother:  wg 1300822
# No mother node found for id:  1174  Node with mother:  wg 1300838
# No mother node found for id:  1175  Node with mother:  wg 1300837
# No mother node found for id:  1194  Node with mother:  wg 1300844
# No mother node found for id:  1195  Node with mother:  wg 1300843
# No mother node found for id:  1206  Node with mother:  wg 1300848
# No mother node found for id:  1207  Node with mother:  wg 1300847
# No mother node found for id:  1213  Node with mother:  wg 1300850
# No mother node found for id:  1215  Node with mother:  wg 427783
# No mother node found for id:  1218  Node with mother:  wg 1300852
# No mother node found for id:  1247  Node with mother:  wg 427792
# No mother node found for id:  1256  Node with mother:  wg 427795
# No mother node found for id:  1257  Node with mother:  wg 1300856
# No mother node found for id:  1300  Node with mother:  wg 1300860
# No mother node found for id:  1309  Node with mother:  wg 1300862
# No mother node found for id:  1318  Node with mother:  wg 1300866
# No mother node found for id:  1319  Node with mother:  wg 427811
# No mother node found for id:  1326  Node with mother:  wg 1300868
# No mother node found for id:  1336  Node with mother:  wg 1300874
# No mother node found for id:  1340  Node with mother:  wg 1300878
# No mother node found for id:  1341  Node with mother:  wg 1300877
# No mother node found for id:  1438  Node with mother:  wg 1300886
# No mother node found for id:  1443  Node with mother:  wg 1300891
# No mother node found for id:  1444  Node with mother:  wg 1300890
# No mother node found for id:  1453  Node with mother:  wg 1300896
# No mother node found for id:  1454  Node with mother:  wg 1300895
# No mother node found for id:  1505  Node with mother:  wg 1300906
# No mother node found for id:  1527  Node with mother:  wg 1300910
# No mother node found for id:  1528  Node with mother:  wg 1300909
# No mother node found for id:  1539  Node with mother:  wg 1300914
# No mother node found for id:  1543  Node with mother:  wg 1300916
# No mother node found for id:  1566  Node with mother:  wg 1300918
# No mother node found for id:  1572  Node with mother:  wg 1300922
# No mother node found for id:  1573  Node with mother:  wg 1300921
# No mother node found for id:  1584  Node with mother:  wg 1300928
# No mother node found for id:  1627  Node with mother:  wg 1300940
# No mother node found for id:  1648  Node with mother:  wg 1300942
# No mother node found for id:  1655  Node with mother:  wg 1300945
# No mother node found for id:  1657  Node with mother:  wg 427882
# No mother node found for id:  1663  Node with mother:  wg 1300950
# No mother node found for id:  1664  Node with mother:  wg 1300949
# No mother node found for id:  1697  Node with mother:  wg 1300952
# No mother node found for id:  1702  Node with mother:  wg 1300954
# No mother node found for id:  1707  Node with mother:  wg 1300956
# No mother node found for id:  1713  Node with mother:  wg 1300958
# No mother node found for id:  1725  Node with mother:  wg 1300962
# No mother node found for id:  1828  Node with mother:  wg 1300972
# No mother node found for id:  1829  Node with mother:  wg 1300971
# No mother node found for id:  1850  Node with mother:  wg 1300974
# No mother node found for id:  1887  Node with mother:  wg 1300978
# No mother node found for id:  1904  Node with mother:  wg 427938
# No mother node found for id:  1912  Node with mother:  wg 427941
# No mother node found for id:  1927  Node with mother:  wg 1300982
# No mother node found for id:  1934  Node with mother:  wg 1300984
# No mother node found for id:  1939  Node with mother:  wg 1300986
# No mother node found for id:  1960  Node with mother:  wg 1300988
# No mother node found for id:  1964  Node with mother:  wg 1300990
# No mother node found for id:  1992  Node with mother:  wg 1300992
# No mother node found for id:  1994  Node with mother:  wg 1300994
# No mother node found for id:  1999  Node with mother:  wg 1300996
# No mother node found for id:  2010  Node with mother:  wg 1301002
# No mother node found for id:  2011  Node with mother:  wg 1301001
# No mother node found for id:  2016  Node with mother:  wg 1301004
# No mother node found for id:  2021  Node with mother:  wg 1301010
# No mother node found for id:  2022  Node with mother:  wg 1301009
# No mother node found for id:  2023  Node with mother:  wg 1301008
# No mother node found for id:  2034  Node with mother:  wg 1301018
# No mother node found for id:  2035  Node with mother:  wg 1301017
# No mother node found for id:  2036  Node with mother:  wg 1301016
# No mother node found for id:  2041  Node with mother:  wg 1301020
# No mother node found for id:  2054  Node with mother:  wg 1301024
# No mother node found for id:  2118  Node with mother:  wg 1301032
# No mother node found for id:  2121  Node with mother:  wg 1301036
# No mother node found for id:  2122  Node with mother:  wg 1301035
# No mother node found for id:  2125  Node with mother:  wg 427985
# No mother node found for id:  2130  Node with mother:  wg 1301038
# No mother node found for id:  2147  Node with mother:  wg 427989
# No mother node found for id:  2154  Node with mother:  wg 1301043
# No mother node found for id:  2169  Node with mother:  wg 1301046
# No mother node found for id:  2185  Node with mother:  wg 1301056
# No mother node found for id:  2186  Node with mother:  wg 1301055
# No mother node found for id:  2190  Node with mother:  wg 1301058
# No mother node found for id:  2204  Node with mother:  wg 1301069
# No mother node found for id:  2230  Node with mother:  wg 1301084
# No mother node found for id:  2231  Node with mother:  wg 1301083
# No mother node found for id:  2237  Node with mother:  wg 1301091
# No mother node found for id:  2272  Node with mother:  wg 1301112
# No mother node found for id:  2273  Node with mother:  wg 1301111
# No mother node found for id:  2278  Node with mother:  wg 1301117
# No mother node found for id:  2312  Node with mother:  wg 1301136
# No mother node found for id:  2313  Node with mother:  wg 1301135
# No mother node found for id:  2318  Node with mother:  wg 1301141
# No mother node found for id:  2355  Node with mother:  wg 1301164
# No mother node found for id:  2356  Node with mother:  wg 1301163
# No mother node found for id:  2376  Node with mother:  wg 1301181
# No mother node found for id:  2399  Node with mother:  wg 1301192
# No mother node found for id:  2400  Node with mother:  wg 1301191
# No mother node found for id:  2407  Node with mother:  wg 1301199
# No mother node found for id:  2443  Node with mother:  wg 1301216
# No mother node found for id:  2444  Node with mother:  wg 1301215
# No mother node found for id:  2451  Node with mother:  wg 1301223
# No mother node found for id:  2474  Node with mother:  wg 1301233
# No mother node found for id:  2502  Node with mother:  wg 1301250
# No mother node found for id:  2503  Node with mother:  wg 1301249
# No mother node found for id:  2510  Node with mother:  wg 1301257
# No mother node found for id:  2523  Node with mother:  wg 1301267
# No mother node found for id:  2541  Node with mother:  wg 1301271
# No mother node found for id:  2571  Node with mother:  wg 1301288
# No mother node found for id:  2572  Node with mother:  wg 1301287
# No mother node found for id:  2579  Node with mother:  wg 1301295
# No mother node found for id:  2587  Node with mother:  wg 1301304
# No mother node found for id:  2588  Node with mother:  wg 1301301
# No mother node found for id:  2610  Node with mother:  wg 1301310
# No mother node found for id:  2619  Node with mother:  wg 1301312
# No mother node found for id:  2623  Node with mother:  wg 1301314
# No mother node found for id:  2634  Node with mother:  wg 428070
# No mother node found for id:  2677  Node with mother:  wg 1301324
# No mother node found for id:  2681  Node with mother:  wg 1301326
# No mother node found for id:  2693  Node with mother:  wg 1301328
# No mother node found for id:  2701  Node with mother:  wg 1301330
# No mother node found for id:  2708  Node with mother:  wg 1301336
# No mother node found for id:  2709  Node with mother:  wg 1301335
# No mother node found for id:  2710  Node with mother:  wg 1301334
# No mother node found for id:  2714  Node with mother:  wg 1301338
# No mother node found for id:  2743  Node with mother:  wg 1301340
# No mother node found for id:  2754  Node with mother:  wg 1301345
# No mother node found for id:  2766  Node with mother:  wg 1301348
# No mother node found for id:  2769  Node with mother:  wg 1301350
# No mother node found for id:  2800  Node with mother:  wg 1301362
# No mother node found for id:  2819  Node with mother:  wg 1301364
# No mother node found for id:  2831  Node with mother:  wg 1301368
# No mother node found for id:  2832  Node with mother:  wg 1301367
# No mother node found for id:  2852  Node with mother:  wg 1301372
# No mother node found for id:  2853  Node with mother:  wg 1301371
# No mother node found for id:  2876  Node with mother:  wg 1301376
# No mother node found for id:  2879  Node with mother:  wg 1301380
# No mother node found for id:  2902  Node with mother:  wg 1301386
# No mother node found for id:  2926  Node with mother:  wg 1301394
# No mother node found for id:  2930  Node with mother:  wg 1301396
# No mother node found for id:  2933  Node with mother:  wg 1301398
# No mother node found for id:  2936  Node with mother:  wg 428124
# No mother node found for id:  2958  Node with mother:  wg 1301404
# No mother node found for id:  2963  Node with mother:  wg 1301408
# No mother node found for id:  2967  Node with mother:  wg 1301410
# No mother node found for id:  2995  Node with mother:  wg 1301416
# No mother node found for id:  2996  Node with mother:  wg 1301415
# No mother node found for id:  3013  Node with mother:  wg 1301418
# No mother node found for id:  3014  Node with mother:  wg 428135
# No mother node found for id:  3031  Node with mother:  wg 428139
# No mother node found for id:  3046  Node with mother:  wg 1301423
# No mother node found for id:  3063  Node with mother:  wg 1301430
# No mother node found for id:  3101  Node with mother:  wg 1301446
# No mother node found for id:  3102  Node with mother:  wg 1301445
# No mother node found for id:  3123  Node with mother:  wg 1301456
# No mother node found for id:  3130  Node with mother:  wg 1301458
# No mother node found for id:  3137  Node with mother:  wg 428153
# No mother node found for id:  3143  Node with mother:  wg 1301464
# No mother node found for id:  3144  Node with mother:  wg 1301461
# No mother node found for id:  3163  Node with mother:  wg 1301470
# No mother node found for id:  3170  Node with mother:  wg 1301476
# No mother node found for id:  3171  Node with mother:  wg 1301475
# No mother node found for id:  3182  Node with mother:  wg 428159
# No mother node found for id:  3191  Node with mother:  wg 428160
# No mother node found for id:  3217  Node with mother:  wg 1301488
# No mother node found for id:  3221  Node with mother:  wg 1301490
# No mother node found for id:  3229  Node with mother:  wg 1301496
# No mother node found for id:  3230  Node with mother:  wg 1301493
# No mother node found for id:  3234  Node with mother:  wg 1301498
# No mother node found for id:  3254  Node with mother:  wg 1301512
# No mother node found for id:  3255  Node with mother:  wg 1301511
# No mother node found for id:  3259  Node with mother:  wg 1301514
# No mother node found for id:  3276  Node with mother:  wg 1301524
# No mother node found for id:  3289  Node with mother:  wg 1301532
# No mother node found for id:  3295  Node with mother:  wg 1301537
# No mother node found for id:  3296  Node with mother:  wg 1301536
# No mother node found for id:  3304  Node with mother:  wg 1301541
# No mother node found for id:  3310  Node with mother:  wg 1301544
# No mother node found for id:  3316  Node with mother:  wg 1301546
# No mother node found for id:  3318  Node with mother:  wg 428169
# No mother node found for id:  3327  Node with mother:  wg 1301548
# No mother node found for id:  3332  Node with mother:  wg 1301554
# No mother node found for id:  3333  Node with mother:  wg 1301553
# No mother node found for id:  3334  Node with mother:  wg 1301552
# No mother node found for id:  3346  Node with mother:  wg 1301558
# No mother node found for id:  3351  Node with mother:  wg 1301560
# No mother node found for id:  3411  Node with mother:  wg 1301568
# No mother node found for id:  3425  Node with mother:  wg 1301574
# No mother node found for id:  3432  Node with mother:  wg 1301576
# No mother node found for id:  3435  Node with mother:  wg 1301578
# No mother node found for id:  3450  Node with mother:  wg 1301582
# No mother node found for id:  3482  Node with mother:  wg 428192
# No mother node found for id:  3484  Node with mother:  wg 1301596
# No mother node found for id:  3490  Node with mother:  wg 428193
# No mother node found for id:  3499  Node with mother:  wg 1301598
# No mother node found for id:  3504  Node with mother:  wg 1301600
# No mother node found for id:  3515  Node with mother:  wg 1301605
# No mother node found for id:  3542  Node with mother:  wg 1301611
# No mother node found for id:  3551  Node with mother:  wg 1301615
# No mother node found for id:  3556  Node with mother:  wg 1301619
# No mother node found for id:  3558  Node with mother:  wg 428201
# No mother node found for id:  3577  Node with mother:  wg 1301622
# No mother node found for id:  3580  Node with mother:  wg 1301625
# No mother node found for id:  3606  Node with mother:  wg 1301634
# No mother node found for id:  3609  Node with mother:  wg 1301632
# No mother node found for id:  3628  Node with mother:  wg 1301642
# No mother node found for id:  3651  Node with mother:  wg 1301648
# No mother node found for id:  3657  Node with mother:  wg 1301652
# No mother node found for id:  3664  Node with mother:  wg 1301654
# No mother node found for id:  3702  Node with mother:  wg 1301658
# No mother node found for id:  3712  Node with mother:  wg 1301660
# No mother node found for id:  3723  Node with mother:  wg 1301664
# No mother node found for id:  3724  Node with mother:  wg 1301663
# No mother node found for id:  3742  Node with mother:  wg 1301668
# No mother node found for id:  3760  Node with mother:  wg 1301670
# No mother node found for id:  3764  Node with mother:  wg 1301674
# No mother node found for id:  3783  Node with mother:  wg 1301678
# No mother node found for id:  3802  Node with mother:  wg 1301681
# No mother node found for id:  3824  Node with mother:  wg 1301686
# No mother node found for id:  3832  Node with mother:  wg 1301688
# No mother node found for id:  3869  Node with mother:  wg 1301700
# No mother node found for id:  3872  Node with mother:  wg 1301704
# No mother node found for id:  3878  Node with mother:  wg 1301706
# No mother node found for id:  3889  Node with mother:  wg 1301711
# No mother node found for id:  3891  Node with mother:  wg 428248
# No mother node found for id:  3919  Node with mother:  wg 1301718
# No mother node found for id:  3922  Node with mother:  wg 1301722
# No mother node found for id:  3925  Node with mother:  wg 1301724
# No mother node found for id:  3929  Node with mother:  wg 1301727
# No mother node found for id:  3932  Node with mother:  wg 428254
# No mother node found for id:  3952  Node with mother:  wg 1301732
# No mother node found for id:  3959  Node with mother:  wg 1301737
# No mother node found for id:  3974  Node with mother:  wg 1301740
# No mother node found for id:  3991  Node with mother:  wg 1301742
# No mother node found for id:  3995  Node with mother:  wg 1301746
# No mother node found for id:  3996  Node with mother:  wg 1301745
# No mother node found for id:  4009  Node with mother:  wg 1301748
# No mother node found for id:  4015  Node with mother:  wg 1301752
# No mother node found for id:  4016  Node with mother:  wg 1301751
# No mother node found for id:  4061  Node with mother:  wg 1301774
# No mother node found for id:  4062  Node with mother:  wg 1301773
# No mother node found for id:  4067  Node with mother:  wg 1301779
# No mother node found for id:  4068  Node with mother:  wg 1301778
# No mother node found for id:  4072  Node with mother:  wg 428274
# No mother node found for id:  4079  Node with mother:  wg 1301784
# No mother node found for id:  4080  Node with mother:  wg 1301783
# No mother node found for id:  4086  Node with mother:  wg 1301786
# No mother node found for id:  4117  Node with mother:  wg 1301796
# No mother node found for id:  4118  Node with mother:  wg 1301795
# No mother node found for id:  4123  Node with mother:  wg 1301798
# No mother node found for id:  4127  Node with mother:  wg 1301802
# No mother node found for id:  4128  Node with mother:  wg 1301801
# No mother node found for id:  4132  Node with mother:  wg 1301804
# No mother node found for id:  4135  Node with mother:  wg 1301808
# No mother node found for id:  4136  Node with mother:  wg 1301807
# No mother node found for id:  4146  Node with mother:  wg 1301810
# No mother node found for id:  4188  Node with mother:  wg 1301818
# No mother node found for id:  4189  Node with mother:  wg 1301817
# No mother node found for id:  4202  Node with mother:  wg 1301825
# No mother node found for id:  4203  Node with mother:  wg 1301824
# No mother node found for id:  4208  Node with mother:  wg 428297
# No mother node found for id:  4213  Node with mother:  wg 1301830
# No mother node found for id:  4214  Node with mother:  wg 1301829
# No mother node found for id:  4225  Node with mother:  wg 1301832
# No mother node found for id:  4229  Node with mother:  wg 1301834
# No mother node found for id:  4245  Node with mother:  wg 1301836
# No mother node found for id:  4256  Node with mother:  wg 1301843
# No mother node found for id:  4257  Node with mother:  wg 428305
# No mother node found for id:  4262  Node with mother:  wg 1301846
# No mother node found for id:  4273  Node with mother:  wg 1301848
# No mother node found for id:  4305  Node with mother:  wg 1301857
# No mother node found for id:  4309  Node with mother:  wg 1301860
# No mother node found for id:  4321  Node with mother:  wg 1301862
# No mother node found for id:  4334  Node with mother:  wg 1301864
# No mother node found for id:  4340  Node with mother:  wg 1301869
# No mother node found for id:  4344  Node with mother:  wg 1301872
# No mother node found for id:  4356  Node with mother:  wg 1301874
# No mother node found for id:  4364  Node with mother:  wg 1301877
# No mother node found for id:  4365  Node with mother:  wg 428322
# No mother node found for id:  4372  Node with mother:  wg 1301880
# No mother node found for id:  4387  Node with mother:  wg 1301886
# No mother node found for id:  4391  Node with mother:  wg 1301890
# No mother node found for id:  4397  Node with mother:  wg 1301892
# No mother node found for id:  4403  Node with mother:  wg 1301894
# No mother node found for id:  4419  Node with mother:  wg 1301896
# No mother node found for id:  4424  Node with mother:  wg 1301898
# No mother node found for id:  4427  Node with mother:  wg 1301900
# No mother node found for id:  4432  Node with mother:  wg 1301902
# No mother node found for id:  4448  Node with mother:  wg 1301906
# No mother node found for id:  4456  Node with mother:  wg 1301908
# No mother node found for id:  4462  Node with mother:  wg 1301910
# No mother node found for id:  4484  Node with mother:  wg 1301914
# No mother node found for id:  4493  Node with mother:  wg 1301916
# No mother node found for id:  4507  Node with mother:  wg 1301918
# No mother node found for id:  4520  Node with mother:  wg 1301920
# No mother node found for id:  4528  Node with mother:  wg 1301930
# No mother node found for id:  4529  Node with mother:  wg 1301929
# No mother node found for id:  4531  Node with mother:  wg 1301932
# No mother node found for id:  4541  Node with mother:  wg 1301942
# No mother node found for id:  4542  Node with mother:  wg 1301941
# No mother node found for id:  4555  Node with mother:  wg 1301948
# No mother node found for id:  4571  Node with mother:  wg 1301962
# No mother node found for id:  4579  Node with mother:  wg 1301968
# No mother node found for id:  4590  Node with mother:  wg 1301976
# No mother node found for id:  4603  Node with mother:  wg 1301978
# No mother node found for id:  4613  Node with mother:  wg 1301986
# No mother node found for id:  4625  Node with mother:  wg 1301996
# No mother node found for id:  4645  Node with mother:  wg 1302000
# No mother node found for id:  4648  Node with mother:  wg 1302002
# No mother node found for id:  4655  Node with mother:  wg 1302004
# No mother node found for id:  4658  Node with mother:  wg 1302006
# No mother node found for id:  4662  Node with mother:  wg 1302008
# No mother node found for id:  4672  Node with mother:  wg 1302016
# No mother node found for id:  4780  Node with mother:  wg 1302048
# No mother node found for id:  4785  Node with mother:  wg 1302050
# No mother node found for id:  4805  Node with mother:  wg 1302058
# No mother node found for id:  4825  Node with mother:  wg 1302068
# No mother node found for id:  4821  Node with mother:  wg 1302066
# No mother node found for id:  4822  Node with mother:  wg 1302065
# No mother node found for id:  4823  Node with mother:  wg 1302064
# No mother node found for id:  4829  Node with mother:  wg 1302072
# No mother node found for id:  4841  Node with mother:  wg 1302082
# No mother node found for id:  4864  Node with mother:  wg 1302090
# No mother node found for id:  4866  Node with mother:  wg 1302092
# No mother node found for id:  4877  Node with mother:  wg 1302094
# No mother node found for id:  4921  Node with mother:  wg 1302114
# No mother node found for id:  4923  Node with mother:  wg 1302116
# No mother node found for id:  4932  Node with mother:  wg 1302118
# No mother node found for id:  4936  Node with mother:  wg 1302120
# No mother node found for id:  4947  Node with mother:  wg 1302124
# No mother node found for id:  4948  Node with mother:  wg 1302123
# No mother node found for id:  4968  Node with mother:  wg 1302126
# No mother node found for id:  4986  Node with mother:  wg 1302134
# No mother node found for id:  5038  Node with mother:  wg 1302140
# No mother node found for id:  5039  Node with mother:  wg 1302139
# No mother node found for id:  5056  Node with mother:  wg 1302144
# No mother node found for id:  5080  Node with mother:  wg 428439
# No mother node found for id:  5095  Node with mother:  wg 1302150
# No mother node found for id:  5104  Node with mother:  wg 1302154
# No mother node found for id:  5105  Node with mother:  wg 1302153
# No mother node found for id:  5123  Node with mother:  wg 1302158
# No mother node found for id:  5124  Node with mother:  wg 1302157
# No mother node found for id:  5133  Node with mother:  wg 1302162
# No mother node found for id:  5134  Node with mother:  wg 1302161
# No mother node found for id:  5138  Node with mother:  wg 1302164
# No mother node found for id:  5141  Node with mother:  wg 1302168
# No mother node found for id:  5142  Node with mother:  wg 1302167
# No mother node found for id:  5374  Node with mother:  wg 1302264
# No mother node found for id:  5394  Node with mother:  wg 1302270
# No mother node found for id:  5398  Node with mother:  wg 1302272
# No mother node found for id:  5410  Node with mother:  wg 1302280
# No mother node found for id:  5411  Node with mother:  wg 1302279
# No mother node found for id:  5415  Node with mother:  wg 1302284
# No mother node found for id:  5416  Node with mother:  wg 1302283
# No mother node found for id:  5419  Node with mother:  wg 1302286
# No mother node found for id:  5421  Node with mother:  wg 1302288
# No mother node found for id:  5424  Node with mother:  wg 1302291
# No mother node found for id:  5442  Node with mother:  wg 1302294
# No mother node found for id:  5444  Node with mother:  wg 1302296
# No mother node found for id:  5450  Node with mother:  wg 1302298
# No mother node found for id:  5461  Node with mother:  wg 1302302
# No mother node found for id:  5472  Node with mother:  wg 1302304
# No mother node found for id:  5498  Node with mother:  wg 1302315
# No mother node found for id:  5527  Node with mother:  wg 1302322
# No mother node found for id:  5528  Node with mother:  wg 1302321
# No mother node found for id:  5545  Node with mother:  wg 1302324
# No mother node found for id:  5564  Node with mother:  wg 1302332
# No mother node found for id:  5568  Node with mother:  wg 1302334
# No mother node found for id:  5584  Node with mother:  wg 1302336
# No mother node found for id:  5588  Node with mother:  wg 1302338
# No mother node found for id:  5597  Node with mother:  wg 1302340
# No mother node found for id:  5600  Node with mother:  wg 1302342
# No mother node found for id:  5663  Node with mother:  wg 1302346
# No mother node found for id:  5711  Node with mother:  wg 1302351
# No mother node found for id:  5765  Node with mother:  wg 1302354
# No mother node found for id:  5776  Node with mother:  wg 1302356
# No mother node found for id:  5811  Node with mother:  wg 1302372
# No mother node found for id:  5813  Node with mother:  wg 1302374
# No mother node found for id:  5863  Node with mother:  wg 428590
# No mother node found for id:  5875  Node with mother:  wg 428592
# No mother node found for id:  5923  Node with mother:  wg 1302392
# No mother node found for id:  5925  Node with mother:  wg 428598
# No mother node found for id:  5937  Node with mother:  wg 1302394
# No mother node found for id:  5976  Node with mother:  wg 1302402
# No mother node found for id:  5977  Node with mother:  wg 1302401
# No mother node found for id:  5981  Node with mother:  wg 1302407
# No mother node found for id:  5982  Node with mother:  wg 1302406
# No mother node found for id:  6019  Node with mother:  wg 1302418
# No mother node found for id:  6047  Node with mother:  wg 1302422
# No mother node found for id:  6048  Node with mother:  wg 1302421
# No mother node found for id:  6076  Node with mother:  wg 1302432
# No mother node found for id:  6077  Node with mother:  wg 1302431
# No mother node found for id:  6094  Node with mother:  wg 1302434
# No mother node found for id:  6100  Node with mother:  wg 1302436
# No mother node found for id:  6108  Node with mother:  wg 1302438
# No mother node found for id:  6146  Node with mother:  wg 1302448
# No mother node found for id:  6164  Node with mother:  wg 1302450
# No mother node found for id:  6174  Node with mother:  wg 1302452
# No mother node found for id:  6201  Node with mother:  wg 1302458
# No mother node found for id:  6215  Node with mother:  wg 1302460
# No mother node found for id:  6217  Node with mother:  wg 1302462
# No mother node found for id:  6220  Node with mother:  wg 1302464
# No mother node found for id:  6223  Node with mother:  wg 1302466
# No mother node found for id:  6227  Node with mother:  wg 1302468
# No mother node found for id:  6233  Node with mother:  wg 1302470
# No mother node found for id:  6238  Node with mother:  wg 1302472
# No mother node found for id:  6241  Node with mother:  wg 1302474
# No mother node found for id:  6245  Node with mother:  wg 1302476
# No mother node found for id:  6248  Node with mother:  wg 1302478
# No mother node found for id:  6252  Node with mother:  wg 1302480
# No mother node found for id:  6256  Node with mother:  wg 1302482
# No mother node found for id:  6260  Node with mother:  wg 1302484
# No mother node found for id:  6270  Node with mother:  wg 1302490
# No mother node found for id:  6276  Node with mother:  wg 1302494
# No mother node found for id:  6283  Node with mother:  wg 428660
# No mother node found for id:  6303  Node with mother:  wg 1302500
# No mother node found for id:  6329  Node with mother:  wg 1302504
# No mother node found for id:  6330  Node with mother:  wg 1302503
# No mother node found for id:  6344  Node with mother:  wg 1302510
# No mother node found for id:  6347  Node with mother:  wg 1302513
# No mother node found for id:  6350  Node with mother:  wg 1302517
# No mother node found for id:  6353  Node with mother:  wg 1302521
# No mother node found for id:  6356  Node with mother:  wg 1302525
# No mother node found for id:  6365  Node with mother:  wg 1302528
# No mother node found for id:  6370  Node with mother:  wg 1302530
# No mother node found for id:  6374  Node with mother:  wg 1302532
# No mother node found for id:  6378  Node with mother:  wg 1302534
# No mother node found for id:  6382  Node with mother:  wg 1302536
# No mother node found for id:  6390  Node with mother:  wg 1302540
# No mother node found for id:  6393  Node with mother:  wg 1302544
# No mother node found for id:  6394  Node with mother:  wg 1302543
# No mother node found for id:  6398  Node with mother:  wg 1302548
# No mother node found for id:  6413  Node with mother:  wg 1302554
# No mother node found for id:  6414  Node with mother:  wg 1302553
# No mother node found for id:  6420  Node with mother:  wg 1302556
# No mother node found for id:  6431  Node with mother:  wg 1302562
# No mother node found for id:  6432  Node with mother:  wg 1302561
# No mother node found for id:  6455  Node with mother:  wg 1302564
# No mother node found for id:  6459  Node with mother:  wg 1302566
# No mother node found for id:  6462  Node with mother:  wg 1302569
# No mother node found for id:  6466  Node with mother:  wg 1302574
# No mother node found for id:  6467  Node with mother:  wg 1302573
# No mother node found for id:  6479  Node with mother:  wg 1302576
# No mother node found for id:  6484  Node with mother:  wg 1302581
# No mother node found for id:  6511  Node with mother:  wg 1302586
# No mother node found for id:  6533  Node with mother:  wg 1302594
# No mother node found for id:  6553  Node with mother:  wg 1302600
# No mother node found for id:  6558  Node with mother:  wg 1302602
# No mother node found for id:  6579  Node with mother:  wg 1302612
# No mother node found for id:  6600  Node with mother:  wg 1302616
# No mother node found for id:  6617  Node with mother:  wg 1302618
# No mother node found for id:  6625  Node with mother:  wg 1302624
# No mother node found for id:  6634  Node with mother:  wg 1302627
# No mother node found for id:  6640  Node with mother:  wg 428720
# No mother node found for id:  6657  Node with mother:  wg 1302630
# No mother node found for id:  6659  Node with mother:  wg 428727
# No mother node found for id:  6676  Node with mother:  wg 1302638
# No mother node found for id:  6707  Node with mother:  wg 1302644
# No mother node found for id:  6708  Node with mother:  wg 1302643
# No mother node found for id:  6723  Node with mother:  wg 1302648
# No mother node found for id:  6729  Node with mother:  wg 1302650
# No mother node found for id:  6829  Node with mother:  wg 1302672
# No mother node found for id:  6898  Node with mother:  wg 1302678
# No mother node found for id:  6936  Node with mother:  wg 1302690
# No mother node found for id:  6951  Node with mother:  wg 1302692
# No mother node found for id:  6954  Node with mother:  wg 1302695
# No mother node found for id:  6984  Node with mother:  wg 1302704
# No mother node found for id:  6991  Node with mother:  wg 1302708
# No mother node found for id:  7034  Node with mother:  wg 1302724
# No mother node found for id:  7068  Node with mother:  wg 1302728
# No mother node found for id:  7073  Node with mother:  wg 1302730
# No mother node found for id:  7081  Node with mother:  wg 1302734
# No mother node found for id:  7088  Node with mother:  wg 1302736
# No mother node found for id:  7163  Node with mother:  wg 1302740
# No mother node found for id:  7166  Node with mother:  wg 1302742
# No mother node found for id:  7176  Node with mother:  wg 1302744
# No mother node found for id:  7181  Node with mother:  wg 1302746
# No mother node found for id:  7193  Node with mother:  wg 1302748
# No mother node found for id:  7201  Node with mother:  wg 1302750
# No mother node found for id:  7213  Node with mother:  wg 1302752
# No mother node found for id:  7227  Node with mother:  wg 1302754
# No mother node found for id:  7246  Node with mother:  wg 1302756
# No mother node found for id:  7253  Node with mother:  wg 1302758
# No mother node found for id:  7258  Node with mother:  wg 1302762
# No mother node found for id:  7259  Node with mother:  wg 1302761
# No mother node found for id:  7264  Node with mother:  wg 1302764
# No mother node found for id:  7265  Node with mother:  wg 428859
# No mother node found for id:  7270  Node with mother:  wg 1302766
# No mother node found for id:  7286  Node with mother:  wg 1302770
# No mother node found for id:  7303  Node with mother:  wg 1302774
# No mother node found for id:  7304  Node with mother:  wg 428868
# No mother node found for id:  7311  Node with mother:  wg 1302776
# No mother node found for id:  7327  Node with mother:  wg 1302784
# No mother node found for id:  7342  Node with mother:  wg 1302792
# No mother node found for id:  7380  Node with mother:  wg 1302800
# No mother node found for id:  7381  Node with mother:  wg 1302799
# No mother node found for id:  7395  Node with mother:  wg 1302804
# No mother node found for id:  7396  Node with mother:  wg 1302803
# No mother node found for id:  7427  Node with mother:  wg 1302812
# No mother node found for id:  7446  Node with mother:  wg 1302816
# No mother node found for id:  7449  Node with mother:  wg 1302820
# No mother node found for id:  7450  Node with mother:  wg 1302819
# No mother node found for id:  7453  Node with mother:  wg 1302822
# No mother node found for id:  7489  Node with mother:  wg 1302830
# No mother node found for id:  7494  Node with mother:  wg 1302832
# No mother node found for id:  7499  Node with mother:  wg 1302834
# No mother node found for id:  7505  Node with mother:  wg 1302840
# No mother node found for id:  7506  Node with mother:  wg 1302839
# No mother node found for id:  7530  Node with mother:  wg 1302854
# No mother node found for id:  7533  Node with mother:  wg 1302857
# No mother node found for id:  7541  Node with mother:  wg 1302860
# No mother node found for id:  7550  Node with mother:  wg 1302864
# No mother node found for id:  7593  Node with mother:  wg 1302868
# No mother node found for id:  7610  Node with mother:  wg 1302872
# No mother node found for id:  7618  Node with mother:  wg 1302876
# No mother node found for id:  7653  Node with mother:  wg 1302878
# No mother node found for id:  7722  Node with mother:  wg 1302894
# No mother node found for id:  7723  Node with mother:  wg 1302893
# No mother node found for id:  7727  Node with mother:  wg 1302899
# No mother node found for id:  7728  Node with mother:  wg 1302898
# No mother node found for id:  7730  Node with mother:  wg 1302902
# No mother node found for id:  7733  Node with mother:  wg 1302906
# No mother node found for id:  7734  Node with mother:  wg 1302905
# No mother node found for id:  7739  Node with mother:  wg 1302908
# No mother node found for id:  7742  Node with mother:  wg 1302912
# No mother node found for id:  7754  Node with mother:  wg 1302914
# No mother node found for id:  7761  Node with mother:  wg 1302920
# No mother node found for id:  7766  Node with mother:  wg 1302926
# No mother node found for id:  7767  Node with mother:  wg 1302923
# No mother node found for id:  7773  Node with mother:  wg 1302928
# No mother node found for id:  7776  Node with mother:  wg 1302932
# No mother node found for id:  7787  Node with mother:  wg 1302938
# No mother node found for id:  7788  Node with mother:  wg 1302937
# No mother node found for id:  7790  Node with mother:  wg 1302940
# No mother node found for id:  7793  Node with mother:  wg 1302943
# No mother node found for id:  7797  Node with mother:  wg 1302946
# No mother node found for id:  7806  Node with mother:  wg 1302948
# No mother node found for id:  7811  Node with mother:  wg 1302950
# No mother node found for id:  7859  Node with mother:  wg 1302956
# No mother node found for id:  7871  Node with mother:  wg 1302958
# No mother node found for id:  7901  Node with mother:  wg 1302960
# No mother node found for id:  7917  Node with mother:  wg 1302966
# No mother node found for id:  7938  Node with mother:  wg 1302975
# No mother node found for id:  7940  Node with mother:  wg 428986
# No mother node found for id:  7986  Node with mother:  wg 1302980
# No mother node found for id:  8084  Node with mother:  wg 1302988
# No mother node found for id:  8115  Node with mother:  wg 1302996
# No mother node found for id:  8116  Node with mother:  wg 1302995
# No mother node found for id:  8132  Node with mother:  wg 1303000
# No mother node found for id:  8151  Node with mother:  wg 1303006
# No mother node found for id:  8192  Node with mother:  wg 1303008
# No mother node found for id:  8210  Node with mother:  wg 1303012
# No mother node found for id:  8254  Node with mother:  wg 1303020
# No mother node found for id:  8255  Node with mother:  wg 1303019
# No mother node found for id:  8271  Node with mother:  wg 1303024
# No mother node found for id:  8277  Node with mother:  wg 1303026
# No mother node found for id:  8310  Node with mother:  wg 1303032
# No mother node found for id:  8340  Node with mother:  wg 1303036
# No mother node found for id:  8382  Node with mother:  wg 1303038
# No mother node found for id:  8406  Node with mother:  wg 1303042
# No mother node found for id:  8426  Node with mother:  wg 1303044
# No mother node found for id:  8437  Node with mother:  wg 1303046
# No mother node found for id:  8458  Node with mother:  wg 1303048
# No mother node found for id:  8502  Node with mother:  wg 1303050
# No mother node found for id:  8505  Node with mother:  wg 1303052
# No mother node found for id:  8516  Node with mother:  wg 1303056
# No mother node found for id:  8561  Node with mother:  wg 1303058
# No mother node found for id:  8593  Node with mother:  wg 1303064
# No mother node found for id:  8650  Node with mother:  wg 1303066
# No mother node found for id:  8684  Node with mother:  wg 429171
# No mother node found for id:  8706  Node with mother:  wg 1303078
# No mother node found for id:  8720  Node with mother:  wg 1303080
# No mother node found for id:  8742  Node with mother:  wg 1303084
# No mother node found for id:  8763  Node with mother:  wg 1303087
# No mother node found for id:  8764  Node with mother:  wg 429188
# No mother node found for id:  8770  Node with mother:  wg 1303090
# No mother node found for id:  8783  Node with mother:  wg 1303093
# No mother node found for id:  8787  Node with mother:  wg 1303099
# No mother node found for id:  8788  Node with mother:  wg 1303098
# No mother node found for id:  8791  Node with mother:  wg 1303102
# No mother node found for id:  8822  Node with mother:  wg 1303104
# No mother node found for id:  8926  Node with mother:  wg 1303112
# No mother node found for id:  8966  Node with mother:  wg 1303121
# No mother node found for id:  8971  Node with mother:  wg 1303130
# No mother node found for id:  8972  Node with mother:  wg 1303125
# No mother node found for id:  8976  Node with mother:  wg 1303128
# No mother node found for id:  8986  Node with mother:  wg 1303132
# No mother node found for id:  9001  Node with mother:  wg 1303134
# No mother node found for id:  9006  Node with mother:  wg 1303138
# No mother node found for id:  9012  Node with mother:  wg 1303143
# No mother node found for id:  9013  Node with mother:  wg 1303142
# No mother node found for id:  9022  Node with mother:  wg 1303146
# No mother node found for id:  9026  Node with mother:  wg 1303148
# No mother node found for id:  9035  Node with mother:  wg 1303150
# No mother node found for id:  9048  Node with mother:  wg 1303152
# No mother node found for id:  9071  Node with mother:  wg 1303154
# No mother node found for id:  9087  Node with mother:  wg 1303157
# No mother node found for id:  9108  Node with mother:  wg 1303162
# No mother node found for id:  9109  Node with mother:  wg 1303161
# No mother node found for id:  9208  Node with mother:  wg 1303174
# No mother node found for id:  9209  Node with mother:  wg 1303173
# No mother node found for id:  9223  Node with mother:  wg 1303176
# No mother node found for id:  9240  Node with mother:  wg 1303182
# No mother node found for id:  9241  Node with mother:  wg 1303181
# No mother node found for id:  9251  Node with mother:  wg 1303184
# No mother node found for id:  9276  Node with mother:  wg 1303188
# No mother node found for id:  9303  Node with mother:  wg 1303190
# No mother node found for id:  9333  Node with mother:  wg 1303198
# No mother node found for id:  9337  Node with mother:  wg 1303201
# No mother node found for id:  9353  Node with mother:  wg 1303206
# No mother node found for id:  9375  Node with mother:  wg 1303210
# No mother node found for id:  9396  Node with mother:  wg 429322
# No mother node found for id:  9408  Node with mother:  wg 1303214
# No mother node found for id:  9413  Node with mother:  wg 1303218
# No mother node found for id:  9475  Node with mother:  wg 1303226
# No mother node found for id:  9485  Node with mother:  wg 1303230
# No mother node found for id:  9491  Node with mother:  wg 1303234
# No mother node found for id:  9496  Node with mother:  wg 1303236
# No mother node found for id:  9511  Node with mother:  wg 1303238
# No mother node found for id:  9522  Node with mother:  wg 1303240
# No mother node found for id:  9578  Node with mother:  wg 1303250
# No mother node found for id:  9581  Node with mother:  wg 429361
# No mother node found for id:  9612  Node with mother:  wg 1303256
# No mother node found for id:  9615  Node with mother:  wg 1303258
# No mother node found for id:  9618  Node with mother:  wg 1303260
# No mother node found for id:  9620  Node with mother:  wg 1303262
# No mother node found for id:  9659  Node with mother:  wg 1303264
# No mother node found for id:  9660  Node with mother:  wg 429376
# No mother node found for id:  9675  Node with mother:  wg 1303268
# No mother node found for id:  9676  Node with mother:  wg 1303267
# No mother node found for id:  9685  Node with mother:  wg 1303272
# No mother node found for id:  9686  Node with mother:  wg 1303271
# No mother node found for id:  9701  Node with mother:  wg 429385
# No mother node found for id:  9732  Node with mother:  wg 429393
# No mother node found for id:  9740  Node with mother:  wg 1303276
# No mother node found for id:  9764  Node with mother:  wg 1303284
# No mother node found for id:  9779  Node with mother:  wg 1303286
# No mother node found for id:  9782  Node with mother:  wg 1303288
# No mother node found for id:  9799  Node with mother:  wg 429404
# No mother node found for id:  9835  Node with mother:  wg 1303297
# No mother node found for id:  9855  Node with mother:  wg 1303302
# No mother node found for id:  9856  Node with mother:  wg 1303301
# No mother node found for id:  9871  Node with mother:  wg 1303304
# No mother node found for id:  9883  Node with mother:  wg 1303306
# No mother node found for id:  9890  Node with mother:  wg 1303308
# No mother node found for id:  9907  Node with mother:  wg 1303310
# No mother node found for id:  9912  Node with mother:  wg 1303312
# No mother node found for id:  9931  Node with mother:  wg 1303314
# No mother node found for id:  9960  Node with mother:  wg 1303318
# No mother node found for id:  9995  Node with mother:  wg 1303322
# No mother node found for id:  10003  Node with mother:  wg 1303324
# No mother node found for id:  10017  Node with mother:  wg 1303330
# No mother node found for id:  10026  Node with mother:  wg 429453
# No mother node found for id:  10057  Node with mother:  wg 429459
# No mother node found for id:  10072  Node with mother:  wg 1303340
# No mother node found for id:  10073  Node with mother:  wg 429463
# No mother node found for id:  10078  Node with mother:  wg 1303342
# No mother node found for id:  10073  Node with mother:  wg 1303339
# ...
# No mother node found for id:  424303  Node with mother:  wg 1413636
# No mother node found for id:  424310  Node with mother:  wg 1413638
# No mother node found for id:  424312  Node with mother:  wg 1413640
# No mother node found for id:  424316  Node with mother:  wg 1413644
# No mother node found for id:  424317  Node with mother:  wg 1413643
# No mother node found for id:  424325  Node with mother:  wg 1413648
# No mother node found for id:  424344  Node with mother:  wg 1413654
# No mother node found for id:  424349  Node with mother:  wg 1413656
# No mother node found for id:  424364  Node with mother:  wg 1413662
# No mother node found for id:  424383  Node with mother:  wg 1413666
# No mother node found for id:  424392  Node with mother:  wg 1413668
# No mother node found for id:  424408  Node with mother:  wg 1413670
# No mother node found for id:  424429  Node with mother:  wg 1413672
# No mother node found for id:  424433  Node with mother:  wg 515353
# No mother node found for id:  424442  Node with mother:  wg 1413674
# No mother node found for id:  424449  Node with mother:  wg 1413678
# No mother node found for id:  424468  Node with mother:  wg 1413684
# No mother node found for id:  424473  Node with mother:  wg 1413686
# No mother node found for id:  424528  Node with mother:  wg 1413706
# No mother node found for id:  424555  Node with mother:  wg 1413712
# No mother node found for id:  424562  Node with mother:  wg 1413714
# No mother node found for id:  424576  Node with mother:  wg 1413722
# No mother node found for id:  424604  Node with mother:  wg 1413726
# No mother node found for id:  424609  Node with mother:  wg 1413730
# No mother node found for id:  424610  Node with mother:  wg 1413729
# No mother node found for id:  424618  Node with mother:  wg 1413732
# No mother node found for id:  424669  Node with mother:  wg 1413748
# No mother node found for id:  424675  Node with mother:  wg 1413750
# No mother node found for id:  424679  Node with mother:  wg 1413754
# No mother node found for id:  424685  Node with mother:  wg 1413756
# No mother node found for id:  424690  Node with mother:  wg 1413761
# No mother node found for id:  424700  Node with mother:  wg 1413766
# No mother node found for id:  424701  Node with mother:  wg 1413765
# No mother node found for id:  424707  Node with mother:  wg 1413768
# No mother node found for id:  424712  Node with mother:  wg 1413770
# No mother node found for id:  424718  Node with mother:  wg 1413772
# No mother node found for id:  424738  Node with mother:  wg 1413778
# No mother node found for id:  424753  Node with mother:  wg 1413780
# No mother node found for id:  424773  Node with mother:  wg 1413784
# No mother node found for id:  424780  Node with mother:  wg 1413788
# No mother node found for id:  424788  Node with mother:  wg 515407
# No mother node found for id:  424791  Node with mother:  wg 1413790
# No mother node found for id:  424800  Node with mother:  wg 1413794
# No mother node found for id:  424801  Node with mother:  wg 1413793
# No mother node found for id:  424824  Node with mother:  wg 1413802
# No mother node found for id:  424846  Node with mother:  wg 1413810
# No mother node found for id:  424851  Node with mother:  wg 1413812
# No mother node found for id:  424879  Node with mother:  wg 515422
# No mother node found for id:  424883  Node with mother:  wg 1413814
# No mother node found for id:  424895  Node with mother:  wg 1413816
# No mother node found for id:  424900  Node with mother:  wg 1413818
# No mother node found for id:  424905  Node with mother:  wg 1413823
# No mother node found for id:  424906  Node with mother:  wg 1413822
# No mother node found for id:  424930  Node with mother:  wg 1413826
# No mother node found for id:  424940  Node with mother:  wg 1413828
# No mother node found for id:  424956  Node with mother:  wg 1413832
# No mother node found for id:  424961  Node with mother:  wg 1413834
# No mother node found for id:  424971  Node with mother:  wg 1413836
# No mother node found for id:  424991  Node with mother:  wg 1413840
# No mother node found for id:  424998  Node with mother:  wg 1413842
# No mother node found for id:  425009  Node with mother:  wg 1413844
# No mother node found for id:  425014  Node with mother:  wg 515443
# No mother node found for id:  425033  Node with mother:  wg 1413848
# No mother node found for id:  425035  Node with mother:  wg 1413850
# No mother node found for id:  425037  Node with mother:  wg 1413852
# No mother node found for id:  425061  Node with mother:  wg 1413854
# No mother node found for id:  425111  Node with mother:  wg 1413870
# No mother node found for id:  425112  Node with mother:  wg 1413869
# No mother node found for id:  425086  Node with mother:  wg 1413860
# No mother node found for id:  425097  Node with mother:  wg 1413864
# No mother node found for id:  425098  Node with mother:  wg 1413863
# No mother node found for id:  425127  Node with mother:  wg 1413874
# No mother node found for id:  425142  Node with mother:  wg 1413876
# No mother node found for id:  425155  Node with mother:  wg 1413878
# No mother node found for id:  425185  Node with mother:  wg 1413886
# No mother node found for id:  425202  Node with mother:  wg 1413888
# No mother node found for id:  425229  Node with mother:  wg 1413898
# No mother node found for id:  425230  Node with mother:  wg 1413897
# No mother node found for id:  425238  Node with mother:  wg 1413900
# No mother node found for id:  425241  Node with mother:  wg 1413904
# No mother node found for id:  425242  Node with mother:  wg 1413903
# No mother node found for id:  425245  Node with mother:  wg 1413907
# No mother node found for id:  425254  Node with mother:  wg 1413913
# No mother node found for id:  425267  Node with mother:  wg 1413920
# No mother node found for id:  425268  Node with mother:  wg 1413919
# No mother node found for id:  425269  Node with mother:  wg 1413918
# No mother node found for id:  425274  Node with mother:  wg 1413922
# No mother node found for id:  425288  Node with mother:  wg 1413924
# No mother node found for id:  425313  Node with mother:  wg 1413936
# No mother node found for id:  425326  Node with mother:  wg 515496
# No mother node found for id:  425335  Node with mother:  wg 1413942
# No mother node found for id:  425338  Node with mother:  wg 1413944
# No mother node found for id:  425340  Node with mother:  wg 1413946
# No mother node found for id:  425346  Node with mother:  wg 1413948
# No mother node found for id:  425350  Node with mother:  wg 1413950
# No mother node found for id:  425355  Node with mother:  wg 1413952
# No mother node found for id:  425360  Node with mother:  wg 515501
# No mother node found for id:  425370  Node with mother:  wg 1413954
# No mother node found for id:  425375  Node with mother:  wg 1413956
# No mother node found for id:  425377  Node with mother:  wg 1413958
# No mother node found for id:  425408  Node with mother:  wg 1413966
# No mother node found for id:  425409  Node with mother:  wg 1413965
# No mother node found for id:  425419  Node with mother:  wg 1413968
# No mother node found for id:  425427  Node with mother:  wg 1413970
# No mother node found for id:  425436  Node with mother:  wg 1413972
# No mother node found for id:  425438  Node with mother:  wg 1413974
# No mother node found for id:  425458  Node with mother:  wg 1413976
# No mother node found for id:  425463  Node with mother:  wg 1413978
# No mother node found for id:  425465  Node with mother:  wg 1413980
# No mother node found for id:  425469  Node with mother:  wg 1413982
# No mother node found for id:  425478  Node with mother:  wg 1413986
# No mother node found for id:  425479  Node with mother:  wg 1413985
# No mother node found for id:  425484  Node with mother:  wg 1413988
# No mother node found for id:  425488  Node with mother:  wg 1413992
# No mother node found for id:  425489  Node with mother:  wg 1413991
# No mother node found for id:  425507  Node with mother:  wg 1413994
# No mother node found for id:  425510  Node with mother:  wg 1413996
# No mother node found for id:  425516  Node with mother:  wg 1413998
# No mother node found for id:  425522  Node with mother:  wg 1414003
# No mother node found for id:  425534  Node with mother:  wg 1414008
# No mother node found for id:  425539  Node with mother:  wg 1414011
# No mother node found for id:  425530  Node with mother:  wg 515524
# No mother node found for id:  425543  Node with mother:  wg 1414014
# No mother node found for id:  425566  Node with mother:  wg 1414026
# No mother node found for id:  425567  Node with mother:  wg 1414025
# No mother node found for id:  425583  Node with mother:  wg 1414034
# No mother node found for id:  425598  Node with mother:  wg 1414046
# No mother node found for id:  425608  Node with mother:  wg 1414048
# No mother node found for id:  425612  Node with mother:  wg 1414052
# No mother node found for id:  425630  Node with mother:  wg 1414056
# No mother node found for id:  425656  Node with mother:  wg 1414058
# No mother node found for id:  425659  Node with mother:  wg 1414060
# No mother node found for id:  425670  Node with mother:  wg 1414062
# No mother node found for id:  425705  Node with mother:  wg 1414070
# No mother node found for id:  425706  Node with mother:  wg 1414069
# No mother node found for id:  425720  Node with mother:  wg 1414074
# No mother node found for id:  425740  Node with mother:  wg 1414080
# No mother node found for id:  425745  Node with mother:  wg 1414082
# No mother node found for id:  425750  Node with mother:  wg 1414090
# No mother node found for id:  425758  Node with mother:  wg 1414092
# No mother node found for id:  425783  Node with mother:  wg 1414098
# No mother node found for id:  425784  Node with mother:  wg 1414097
# No mother node found for id:  425799  Node with mother:  wg 1414102
# No mother node found for id:  425802  Node with mother:  wg 1414104
# No mother node found for id:  425808  Node with mother:  wg 1414106
# No mother node found for id:  425822  Node with mother:  wg 1414110
# No mother node found for id:  425825  Node with mother:  wg 1414112
# No mother node found for id:  425835  Node with mother:  wg 1414114
# No mother node found for id:  425840  Node with mother:  wg 1414118
# No mother node found for id:  425841  Node with mother:  wg 1414117
# No mother node found for id:  425858  Node with mother:  wg 1414127
# No mother node found for id:  425872  Node with mother:  wg 1414136
# No mother node found for id:  425880  Node with mother:  wg 1414140
# No mother node found for id:  425890  Node with mother:  wg 1414142
# No mother node found for id:  425913  Node with mother:  wg 1414146
# No mother node found for id:  425922  Node with mother:  wg 1414148
# No mother node found for id:  425953  Node with mother:  wg 1414150
# No mother node found for id:  425956  Node with mother:  wg 1414152
# No mother node found for id:  425963  Node with mother:  wg 1414154
# No mother node found for id:  425992  Node with mother:  wg 1414156
# No mother node found for id:  426005  Node with mother:  wg 1414158
# No mother node found for id:  426008  Node with mother:  wg 1414162
# No mother node found for id:  426022  Node with mother:  wg 1414166
# No mother node found for id:  426048  Node with mother:  wg 1414172
# No mother node found for id:  426049  Node with mother:  wg 1414169
# No mother node found for id:  426057  Node with mother:  wg 1414174
# No mother node found for id:  426069  Node with mother:  wg 1414182
# No mother node found for id:  426070  Node with mother:  wg 1414181
# No mother node found for id:  426076  Node with mother:  wg 1414184
# No mother node found for id:  426081  Node with mother:  wg 1414186
# No mother node found for id:  426089  Node with mother:  wg 1414192
# No mother node found for id:  426105  Node with mother:  wg 1414196
# No mother node found for id:  426115  Node with mother:  wg 1414199
# No mother node found for id:  426118  Node with mother:  wg 1414203
# No mother node found for id:  426122  Node with mother:  wg 1414206
# No mother node found for id:  426145  Node with mother:  wg 1414214
# No mother node found for id:  426154  Node with mother:  wg 1414216
# No mother node found for id:  426165  Node with mother:  wg 1414220
# No mother node found for id:  426171  Node with mother:  wg 1414222
# No mother node found for id:  426183  Node with mother:  wg 1414226
# No mother node found for id:  426184  Node with mother:  wg 1414225
# No mother node found for id:  426197  Node with mother:  wg 1414230
# No mother node found for id:  426198  Node with mother:  wg 1414229
# No mother node found for id:  426211  Node with mother:  wg 1414238
# No mother node found for id:  426212  Node with mother:  wg 1414237
# No mother node found for id:  426221  Node with mother:  wg 1414242
# No mother node found for id:  426231  Node with mother:  wg 1414247
# No mother node found for id:  426241  Node with mother:  wg 1414250
# No mother node found for id:  426245  Node with mother:  wg 1414252
# No mother node found for id:  426256  Node with mother:  wg 1414258
# No mother node found for id:  426257  Node with mother:  wg 1414257
# No mother node found for id:  426258  Node with mother:  wg 1414256
# No mother node found for id:  426269  Node with mother:  wg 1414266
# No mother node found for id:  426272  Node with mother:  wg 1414264
# No mother node found for id:  426278  Node with mother:  wg 1414268
# No mother node found for id:  426289  Node with mother:  wg 1414272
# No mother node found for id:  426296  Node with mother:  wg 1414274
# No mother node found for id:  426301  Node with mother:  wg 1414276
# No mother node found for id:  426326  Node with mother:  wg 1414280
# No mother node found for id:  426341  Node with mother:  wg 1414292
# No mother node found for id:  426342  Node with mother:  wg 1414291
# No mother node found for id:  426348  Node with mother:  wg 1414294
# No mother node found for id:  426357  Node with mother:  wg 1414296
# No mother node found for id:  426361  Node with mother:  wg 1414298
# No mother node found for id:  426377  Node with mother:  wg 1414304
# No mother node found for id:  426389  Node with mother:  wg 1414306
# No mother node found for id:  426395  Node with mother:  wg 1414308
# No mother node found for id:  426401  Node with mother:  wg 1414310
# No mother node found for id:  426495  Node with mother:  wg 1414352
# No mother node found for id:  426499  Node with mother:  wg 1414354
# No mother node found for id:  426502  Node with mother:  wg 1414356
# No mother node found for id:  426410  Node with mother:  wg 1414312
# No mother node found for id:  426428  Node with mother:  wg 1414328
# No mother node found for id:  426429  Node with mother:  wg 1414323
# No mother node found for id:  426430  Node with mother:  wg 1414322
# No mother node found for id:  426439  Node with mother:  wg 1414332
# No mother node found for id:  426440  Node with mother:  wg 1414331
# No mother node found for id:  426443  Node with mother:  wg 1414337
# No mother node found for id:  426455  Node with mother:  wg 1414340
# No mother node found for id:  426461  Node with mother:  wg 1414342
# No mother node found for id:  426464  Node with mother:  wg 1414344
# No mother node found for id:  426471  Node with mother:  wg 1414348
# No mother node found for id:  426472  Node with mother:  wg 1414347
# No mother node found for id:  426510  Node with mother:  wg 1414360
# No mother node found for id:  426511  Node with mother:  wg 1414359
# No mother node found for id:  426521  Node with mother:  wg 1414364
# No mother node found for id:  426525  Node with mother:  wg 1414366
# No mother node found for id:  426529  Node with mother:  wg 1414368
# No mother node found for id:  426532  Node with mother:  wg 1414370
# No mother node found for id:  426545  Node with mother:  wg 1414376
# No mother node found for id:  426556  Node with mother:  wg 1414380
# No mother node found for id:  426558  Node with mother:  wg 1414384
# No mother node found for id:  426559  Node with mother:  wg 1414383
# No mother node found for id:  426565  Node with mother:  wg 1414386
# No mother node found for id:  426584  Node with mother:  wg 1414388

# %%
# Print the root (ignore all node attributes except id, mother, and rela), and the move_nodes_to_mother version of the root, to see the difference

def _keep_attribs(node):
    node_minimal = etree.Element(node.tag)
    if 'id' in node.attrib:
        node_minimal.attrib['id'] = node.attrib['id']
    if 'mother' in node.attrib:
        node_minimal.attrib['mother'] = node.attrib['mother']
    if 'rela' in node.attrib:
        node_minimal.attrib['rela'] = node.attrib['rela']
    for child in node:
        node_minimal.append(_keep_attribs(child))
    return node_minimal

root_minimal = _keep_attribs(root)
root_minimal_first_sentence_child = root_minimal[6]
print(etree.tostring(root_minimal_first_sentence_child, pretty_print=True, encoding='unicode'))
print('\n----------------\n')

# Cleaned up root_minimal_first_sentence_child
move_nodes_to_mother(root_minimal_first_sentence_child)
    
# Print the root (ignore all node attributes except id, mother, and rela), and the move_nodes_to_mother version of the root, to see the difference
print(etree.tostring(root_minimal_first_sentence_child, pretty_print=True, encoding='unicode'))
# Out:
# <sentence id="1235973">
#   <wg id="515611">
#     <wg id="904539">
#       <w id="1"/>
#     </wg>
#     <wg id="904540">
#       <w id="2"/>
#     </wg>
#     <wg id="904541">
#       <wg id="1414205">
#         <w id="3"/>
#       </wg>
#       <wg id="1414206" mother="426122" rela="rec">
#         <w id="4"/>
#       </wg>
#     </wg>
#     <wg id="904542">
#       <w id="5"/>
#       <w id="6"/>
#       <w id="7"/>
#     </wg>
#     <wg id="904543">
#       <w id="8"/>
#       <wg id="1414207">
#         <w id="9"/>
#       </wg>
#       <w id="10"/>
#       <wg id="1414208" mother="1414207" rela="par">
#         <w id="11"/>
#       </wg>
#     </wg>
#   </wg>
# </sentence>
#
#
# ----------------
#
# No mother node found for id:  426122  Node with mother:  wg 1414206
# <sentence id="1235973">
#   <wg id="515611">
#     <wg id="904539">
#       <w id="1"/>
#     </wg>
#     <wg id="904540">
#       <w id="2"/>
#     </wg>
#     <wg id="904541">
#       <wg id="1414205">
#         <w id="3"/>
#       </wg>
#       <wg id="1414206" mother="426122" rela="rec">
#         <w id="4"/>
#       </wg>
#     </wg>
#     <wg id="904542">
#       <w id="5"/>
#       <w id="6"/>
#       <w id="7"/>
#     </wg>
#     <wg id="904543">
#       <w id="8"/>
#       <wg id="1414207">
#         <w id="9"/>
#         <wg id="1414208" mother="1414207" rela="par">
#           <w id="11"/>
#         </wg>
#       </wg>
#       <w id="10"/>
#     </wg>
#   </wg>
# </sentence>
